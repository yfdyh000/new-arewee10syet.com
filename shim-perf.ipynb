# %%
import ujson as json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.plotly as py
import urllib2
import datetime
import sys

from moztelemetry.spark import get_pings, get_pings_properties
import moztelemetry.spark

# %pylab inline

from operator import add
# Out:
# Unable to parse whitelist (/home/hadoop/anaconda2/lib/python2.7/site-packages/moztelemetry/histogram-whitelists.json). Assuming all histograms are acceptable.
# Populating the interactive namespace from numpy and matplotlib

# %%
sc.defaultParallelism
# Out:
# 64

# %% [markdown]
# ### Extract a working dataset

# %% [markdown]
# Collect nightly data from builds dated within a 2-week window.

# %%
def fmt_date(d):
    return d.strftime("%Y%m%d")

## Dates bounding the time window to look at.
t1 = fmt_date(datetime.datetime.now() - datetime.timedelta(16)) # go back 16 days
t2 = fmt_date(datetime.datetime.now() - datetime.timedelta(2)) # go back 2 days
t1, t2
# Out:
# ('20160830', '20160913')

# %%
## Collect only saved-session pings (which cover full browser sessions rather than the usual subsessions).

pings = get_pings(sc, app="Firefox", channel="nightly", build_id=(t1, t2), fraction=1.0)

# %%
def parseAddons(addons):
    """ Create a list of enabled add-ons with elements of the form (ID, version). """
    return[(k, v.get("version")) for k, v in addons.iteritems()]

def extract(ping):
    """ Extract relevant fields from each payload.
    
        shims: Reason why add-on shims were used, keyed by add-on ID (enumerated count of reason codes)
        cpowTime: Contiguous time spent by an add-on blocking the main loop by performing a blocking
                  cross-process call (microseconds, keyed by add-on ID).
        cpowForbidden: Number of times an add-on used CPOWs when it was marked as e10s compatible
                       (count, keyed by add-on ID).
        addons: List of (ID, version) for each enabled add-on.
    """
    hists = ping["payload"].get("histograms", {})
    keyed = ping["payload"].get("keyedHistograms", {})
    clientId = ping.get("clientId", None)
    return {
        "clientId": ping.get("clientId", None),
        "os": ping["environment"]["system"]["os"]["name"],
        "e10s": ping["environment"]["settings"]["e10sEnabled"],
        "sessionLength": ping["payload"]["info"]["sessionLength"], ## in seconds
        "shims": keyed.get("ADDON_SHIM_USAGE", {}),
        "cpowTime": keyed.get("PERF_MONITORING_SLOW_ADDON_CPOW_US", {}),
        "cpowForbidden": keyed.get("ADDON_FORBIDDEN_CPOW_USAGE", {}),
        "addons": parseAddons(ping["environment"].get("addons", {}).get("activeAddons", {}))
    }

## Extract relevant data, and restrict to clients that have add-ons.
bySession = pings.map(extract)\
    .filter(lambda p: p["addons"])\
    .persist(StorageLevel.MEMORY_AND_DISK_SER)

# %% [markdown]
# The `bySession` dataset has one record per client session which had enabled add-ons.
#
# How many session pings are in the dataset?

# %%
bySession.count()
# Out:
# 916124

# %% [markdown]
# How many unique clients do these come from?

# %%
bySession.map(lambda p: p["clientId"]).distinct().count()
# Out:
# 54137

# %% [markdown]
# How many add-ons are represented in the dataset, and what are the top few?

# %%
addonCounts = bySession.flatMap(lambda p: [(guid, p["clientId"]) for (guid, version) in p["addons"]])\
    .distinct()\
    .map(lambda (guid, clientid): guid)\
    .countByValue()
len(addonCounts)
# Out:
# 7268

# %%
sorted(addonCounts.items(), key = lambda (guid, count): (-count, guid))[:20]
# Out:
# [(u'flyweb@mozilla.org', 53991),
#  (u'webcompat@mozilla.org', 53953),
#  (u'e10srollout@mozilla.org', 53885),
#  (u'firefox@getpocket.com', 53720),
#  (u'{d10d0bf8-f5b5-c8b4-a8b2-2b9879e08c5d}', 10761),
#  (u'uBlock0@raymondhill.net', 4520),
#  (u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', 2616),
#  (u'{e4a8a97b-f2ed-450b-b12d-ee082ba24781}', 2451),
#  (u'{DDC359D1-844A-42a7-9AA1-88A850A938A8}', 1710),
#  (u'{73a6fe31-595d-460b-a920-fcc0f8843232}', 1602),
#  (u'firebug@software.joehewitt.com', 1501),
#  (u'{46551EC9-40F0-4e47-8E18-8E5CF550CFB8}', 1339),
#  (u'firefox@mega.co.nz', 1302),
#  (u'firefox@ghostery.com', 1222),
#  (u'{b9bfaf1c-a63f-47cd-8b9a-29526ced9060}', 1155),
#  (u'adbhelper@mozilla.org', 1139),
#  (u'fxdevtools-adapters@mozilla.org', 1108),
#  (u'loop@mozilla.org', 1080),
#  (u'wrc@avast.com', 1037),
#  (u'support@lastpass.com', 1019)]

# %% [markdown]
# ### Shims

# %% [markdown]
# Count enabled add-on installs (ID and version), together with whether or not they were observed to use shims.
#
# An add-on is counted as using shims if it has entry in the `ADDON_SHIM_USAGE` keyed histogram for at least one client session (regardless of the values in the histogram). This histogram records shim usage occurrence by the [reason it was used](https://dxr.mozilla.org/mozilla-central/source/toolkit/components/addoncompat/CompatWarning.jsm#94).

# %%
## Summarize shim usage per add-on/client.
## Reduce multiple sessions observed for each client to
## a single entry of the form ((ID, version), clientID, usedShims).

def getShimData(d):
    """ Summarize each add-on in the ping as (((GUID, version), clientID), <used shims?>). """
    return [((addonv, d["clientId"]), addonv[0] in d["shims"]) for addonv in d["addons"]]

shimUsageByClient = bySession.flatMap(getShimData)\
    .reduceByKey(lambda a, b: a or b)\
    .map(lambda ((addon, clientId), usedShims): (addon, clientId, usedShims))

# %%
## Compute number of clients that used shims for each add-on.
## Result is of the form ((ID, version), usedShims, # clients).

shimUsageCounts = shimUsageByClient\
    .map(lambda (addon, clientId, usedShims): ((addon, usedShims), 1))\
    .reduceByKey(add)\
    .map(lambda ((addon, usedShims), count): (addon, usedShims, count))

# %%
## For each (add-on, version) pair, determine whether it ever used shims,
## along with its overall installation count.
## Result is of the form
##  ((ID, version), <used shims in at least one client session>, overall # installations).

shimUsageByAddon = shimUsageCounts\
    .map(lambda (addon, usedShims, count): (addon, (usedShims, count)))\
    .reduceByKey(lambda (s1, c1), (s2, c2): (s1 or s2, c1 + c2))\
    .map(lambda (addon, (usedShims, count)): (addon, usedShims, count))

# %% [markdown]
# Sanity check: how many add-on (GUID, version) pairs do we have?

# %%
shimUsageByAddon.count()
# Out:
# 9930

# %% [markdown]
# Our final shim usage dataset is restricted to add-ons that were installed/enabled in at least 50 profiles.

# %%
## Order by decreasing installation count.
shimUsageFiltered = shimUsageByAddon.filter(lambda v: v[-1] >= 50)\
    .sortBy(lambda v: (-v[-1], v[:-1]))\
    .collect()

# %% [markdown]
# How many add-ons are in the final dataset?

# %%
len(shimUsageFiltered)
# Out:
# 518

# %% [markdown]
# How many of these used shims?

# %%
shimUsageShimmed = filter(lambda (addon, usedShims, count): usedShims, shimUsageFiltered)
len(shimUsageShimmed)
# Out:
# 270

# %% [markdown]
# Dump results to a JSON file that will be used in the HTML page.
#
# The file is one big JSON array with elements of the form `[<numInstallations>, [<GUID>, <version>], <usedShims>]`.

# %%
def formatForJSON(d):
    return (d[-1],) + d[:-1]

shimUsageOutput = map(formatForJSON, shimUsageFiltered)

try:
    output = open('output/shim-data.json', 'w')
    json.dump(shimUsageOutput, output)
    output.close()
except:
    pass

try:
    output = open('shim-data.json', 'w')
    json.dump(shimUsageOutput, output)
    output.close()
except:
    pass

# %% [markdown]
# The shim usage data, orderd by decreasing installation count.

# %%
shimUsageFiltered
# Out:
# [((u'flyweb@mozilla.org', u'1.0.0'), False, 53991),
#  ((u'webcompat@mozilla.org', u'1.0'), False, 53953),
#  ((u'firefox@getpocket.com', u'1.0.4'), True, 53718),
#  ((u'e10srollout@mozilla.org', u'1.2'), False, 50207),
#  ((u'e10srollout@mozilla.org', u'1.0'), False, 29169),
#  ((u'{d10d0bf8-f5b5-c8b4-a8b2-2b9879e08c5d}', u'2.7.3'), True, 10516),
#  ((u'uBlock0@raymondhill.net', u'1.9.4'), True, 3710),
#  ((u'uBlock0@raymondhill.net', u'1.9.6'), True, 3036),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.0'), True, 2499),
#  ((u'{e4a8a97b-f2ed-450b-b12d-ee082ba24781}', u'3.9'), True, 2318),
#  ((u'firebug@software.joehewitt.com', u'2.0.17'), False, 1365),
#  ((u'{DDC359D1-844A-42a7-9AA1-88A850A938A8}', u'3.0.6'), False, 1340),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.14'), True, 1299),
#  ((u'{46551EC9-40F0-4e47-8E18-8E5CF550CFB8}', u'2.0.7'), False, 1268),
#  ((u'firefox@ghostery.com', u'6.3.2'), True, 1179),
#  ((u'adbhelper@mozilla.org', u'0.8.7'), False, 1131),
#  ((u'fxdevtools-adapters@mozilla.org', u'0.3.5'), True, 1099),
#  ((u'{b9bfaf1c-a63f-47cd-8b9a-29526ced9060}', u'1.8.8'), False, 1027),
#  ((u'loop@mozilla.org', u'1.5.0'), False, 971),
#  ((u'firefox@mega.co.nz', u'3.5.2'), True, 967),
#  ((u'{19503e42-ca3c-4c27-b1e2-9cdb2170ee34}', u'1.5.6.13'), True, 919),
#  ((u'@mozillawebvrenabler', u'0.5.0'), True, 902),
#  ((u'firefox@mega.co.nz', u'3.5.3'), True, 884),
#  ((u'{DDC359D1-844A-42a7-9AA1-88A850A938A8}', u'2.0.19'), True, 882),
#  ((u'adblockpopups@jessehakanen.net', u'0.9.2.1-signed.1-signed'), True, 877),
#  ((u'{DDC359D1-844A-42a7-9AA1-88A850A938A8}', u'3.0.5'), False, 853),
#  ((u'feca4b87-3be4-43da-a1b1-137c24220968@jetpack', u'0.5.4'), True, 798),
#  ((u'jid1-xUfzOsOFlzSOXg@jetpack', u'5.0.1'), True, 791),
#  ((u'{b9bfaf1c-a63f-47cd-8b9a-29526ced9060}', u'1.8.7'), False, 781),
#  ((u'artur.dubovoy@gmail.com', u'13.2.4'), True, 766),
#  ((u'{1280606b-2510-4fe0-97ef-9b5a22eafe30}', u'0.8.1.12'), True, 752),
#  ((u'@testpilot-addon', u'0.8.5-tag-2016-08-25-1'), True, 736),
#  ((u'tabgroups@quicksaver', u'2.0.1'), True, 709),
#  ((u'{1018e4d6-728f-4b20-ad56-37578a4de76b}', u'5.1.14'), True, 689),
#  ((u'https-everywhere@eff.org', u'5.2.4'), False, 688),
#  ((u'firefox@mega.co.nz', u'3.4.48'), True, 667),
#  ((u'{dc572301-7619-498c-a57d-39143191b318}', u'0.5.0.0'), False, 657),
#  ((u'https-everywhere@eff.org', u'5.2.3'), True, 650),
#  ((u'support@lastpass.com', u'3.3.1'), True, 645),
#  ((u'wrc@avast.com', u'12.0.88'), True, 636),
#  ((u'www.facebook.com@services.mozilla.org', u'2'), False, 614),
#  ((u'elemhidehelper@adblockplus.org', u'1.3.9'), True, 584),
#  ((u'{e968fc70-8f95-4ab9-9e79-304de2a71ee1}', u'0.7.3.1-signed.1-signed'),
#   False,
#   584),
#  ((u'jid1-xUfzOsOFlzSOXg@jetpack', u'4.6.1'), True, 573),
#  ((u'sp@avast.com', u'10.3.5.39'), True, 567),
#  ((u'ClassicThemeRestorer@ArisT2Noia4dev', u'1.5.6'), True, 557),
#  ((u'jid1-xUfzOsOFlzSOXg@jetpack', u'5.0.0'), True, 534),
#  ((u'{a0d7ccb3-214d-498b-b4aa-0e8fda9a7bf7}', u'20151208'), True, 534),
#  ((u'translator@zoli.bod', u'2.1.0.5.1.1-signed'), True, 533),
#  ((u'firegestures@xuldev.org', u'1.10.13'), True, 518),
#  ((u'ubufox@ubuntu.com', u'3.2'), False, 481),
#  ((u'YoutubeDownloader@PeterOlayev.com', u'2.4.1'), True, 477),
#  ((u'https-everywhere-eff@eff.org', u'5.2.4'), False, 475),
#  ((u'{bee6eb20-01e0-ebd1-da83-080329fb9a3a}', u'1.86'), True, 474),
#  ((u'helper-sig@savefrom.net', u'6.60'), False, 469),
#  ((u'{7b1bf0b6-a1b9-42b0-b75d-252036438bdc}', u'48.1'), True, 466),
#  ((u'{2b10c1c8-a11f-4bad-fe9c-1c11e82cac42}', u'0.9.5.0.1-let-fixed'),
#   True,
#   462),
#  ((u'jid0-9XfBwUWnvPx4wWsfBWMCm4Jj69E@jetpack', u'0.4.10'), True, 437),
#  ((u'{c45c406e-ab73-11d8-be73-000a95be3b12}', u'1.2.11'), True, 436),
#  ((u'2.0@disconnect.me', u'3.15.3.1-signed.1-signed'), True, 431),
#  ((u'wrc@avast.com', u'10.3.3.44'), True, 428),
#  ((u'{8620c15f-30dc-4dba-a131-7c5d20cf4a29}', u'3.8'), True, 424),
#  ((u'wayback_machine@mozilla.org', u'1.5.6'), False, 423),
#  ((u'{a7c6cf7f-112c-4500-a7ea-39801a327e5f}', u'2.0.28'), True, 421),
#  ((u'{5384767E-00D9-40E9-B72F-9CC39D655D6F}', u'1.5.0.9'), False, 393),
#  ((u'SQLiteManager@mrinalkant.blogspot.com', u'0.8.3.1-signed.1-signed'),
#   False,
#   388),
#  ((u'jid0-GXjLLfbCoAx0LcltEdFrEkQdQPI@jetpack', u'3.0.11'), True, 387),
#  ((u'{d40f5e7b-d2cf-4856-b441-cc613eeffbe3}', u'1.74'), True, 366),
#  ((u's3google@translator', u'5.25'), True, 365),
#  ((u'sovetnik@metabar.ru', u'3.1.4.90'), True, 363),
#  ((u'jid1-q4sG8pYhq8KGHs@jetpack', u'0.2.2'), True, 358),
#  ((u'abs@avira.com', u'1.11.0.828.0'), True, 357),
#  ((u'support@lastpass.com', u'4.1.29a'), False, 350),
#  ((u'adblockultimate@adblockultimate.net', u'2.23'), True, 346),
#  ((u'{E6C1199F-E687-42da-8C24-E7770CC3AE66}', u'2.1.0'), False, 322),
#  ((u'{6c28e999-e900-4635-a39d-b1ec90ba0c0f}', u'14.0.0.0'), False, 318),
#  ((u'info@youtube-mp3.org', u'1.0.9.1-signed.1-signed'), True, 313),
#  ((u'https-everywhere-eff@eff.org', u'5.2.3'), False, 311),
#  ((u'personas@christopher.beard', u'1.8.0'), False, 309),
#  ((u'compatibility@addons.mozilla.org', u'2.2.0'), True, 307),
#  ((u'{f3bd3dd2-2888-44c5-91a2-2caeb33fb898}', u'48.1'), True, 307),
#  ((u'{7b1bf0b6-a1b9-42b0-b75d-252036438bdc}', u'48.2'), True, 304),
#  ((u'{4ED1F68A-5463-4931-9384-8FFF5ED91D92}', u'5.0.226.0'), True, 302),
#  ((u'foxyproxy@eric.h.jung', u'4.5.7'), False, 301),
#  ((u'e67f8350-7edf-11e3-baa7-0800200c9a66@fri-gate.org', u'2.2.1.1-signed'),
#   True,
#   298),
#  ((u'foxmarks@kei.com', u'4.3.19'), True, 298),
#  ((u'www.tumblr.com@services.mozilla.org', u'1'), False, 294),
#  ((u'jid1-F9UJ2thwoAm5gQ@jetpack', u'1.3.1'), True, 293),
#  ((u'jid1-HAV2inXAnQPIeA@jetpack', u'1.7.0'), False, 288),
#  ((u'abs@avira.com', u'1.12.0.9060'), True, 287),
#  ((u'@activity-streams', u'1.1.3'), True, 279),
#  ((u'mail.google.com@services.mozilla.org', u'1'), False, 277),
#  ((u'twitter.com@services.mozilla.org', u'1'), False, 277),
#  ((u'{DDC359D1-844A-42a7-9AA1-88A850A938A8}', u'3.0.2'), False, 276),
#  ((u'firefox@zenmate.com', u'5.7.0'), True, 275),
#  ((u'tabcentertest1@mozilla.com', u'1.24.0'), True, 272),
#  ((u'{b9acf540-acba-11e1-8ccb-001fd0e08bd4}', u'9.09'), True, 272),
#  ((u'compatibility@addons.mozilla.org', u'2.2.1'), False, 270),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.7.0.62'), True, 270),
#  ((u'www.linkedin.com@services.mozilla.org', u'1'), False, 269),
#  ((u'mg.mail.yahoo.com@services.mozilla.org', u'1'), False, 266),
#  ((u'jid1-MnnxcxisBPnSXQ@jetpack', u'1.8.1'), True, 265),
#  ((u'jid1-ZAdIEUB7XOzOJw@jetpack', u'0.5.8'), True, 264),
#  ((u'netvideohunter@netvideohunter.com', u'1.20'), True, 264),
#  ((u'easyscreenshot@mozillaonline.com', u'1.2.8'), True, 261),
#  ((u'adguardadblocker@adguard.com', u'2.3.8'), True, 258),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.14rc1'), True, 258),
#  ((u'firefox@betterttv.net', u'6.8.5'), False, 257),
#  ((u'{fe272bd1-5f76-4ea4-8501-a05d35d823fc}',
#    u'2.1.9.1-signed.1-let-fixed.1-signed'),
#   True,
#   246),
#  ((u'jid1-BoFifL9Vbdl2zQ@jetpack', u'1.3.5'), True, 244),
#  ((u'onepassword4@agilebits.com', u'4.5.9'), True, 240),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.17.2016061501'), False, 240),
#  ((u'jid1-BYcQOfYfmBMd9A@jetpack', u'316'), True, 237),
#  ((u'jsonview@brh.numbera.com', u'1.1.1'), True, 237),
#  ((u'inspector@mozilla.org', u'2.0.16.1-signed'), True, 234),
#  ((u'{bb6bc1bb-f824-4702-90cd-35e2fb24f25d}', u'1.13'), True, 234),
#  ((u'ffext_basicvideoext@startpage24', u'1.97.37.1-signed.1-signed'),
#   True,
#   233),
#  ((u'{B17C1C5A-04B1-11DB-9804-B622A1EF5492}', u'1.3.2'), False, 233),
#  ((u'uMatrix@raymondhill.net', u'0.9.3.6'), True, 232),
#  ((u'{E0B8C461-F8FB-49b4-8373-FE32E9252800}', u'6.2.0'), True, 230),
#  ((u'jid1-7NbXi2AqS1oUFw@jetpack', u'0.2.9'), True, 225),
#  ((u'{3d7eb24f-2740-49df-8937-200b1cc08f8a}', u'1.5.20'), True, 220),
#  ((u'anttoolbar@ant.com', u'2.4.7.43'), True, 217),
#  ((u'support@lastpass.com', u'4.1.26a'), False, 215),
#  ((u'thefoxonlybetter@quicksaver', u'1.4.6'), False, 213),
#  ((u'{64161300-e22b-11db-8314-0800200c9a66}', u'0.9.6.18'), True, 211),
#  ((u'ich@maltegoetz.de', u'2.2.2'), False, 207),
#  ((u'{b9acf540-acba-11e1-8ccb-001fd0e08bd4}', u'9.08'), False, 207),
#  ((u'{dc572301-7619-498c-a57d-39143191b318}', u'0.5.0.1pre.160904a1'),
#   False,
#   207),
#  ((u'twitter.com@services.mozilla.org', u''), False, 206),
#  ((u'{dc572301-7619-498c-a57d-39143191b318}', u'0.5.0.1pre.160625a1'),
#   False,
#   205),
#  ((u'{6AC85730-7D0F-4de0-B3FA-21142DD85326}', u'2.8.2'), True, 204),
#  ((u'privateTab@infocatcher', u'0.2.0'), False, 203),
#  ((u'light_plugin_F6F079488B53499DB99380A7E11A93F6@kaspersky.com',
#    u'5.0.130-0-20160620125320'),
#   True,
#   202),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.18.2016090802'), False, 202),
#  ((u'firefox@mega.co.nz', u'3.5.4'), True, 200),
#  ((u'{7b8a500a-a464-4624-bd4f-73eaafe0f766}', u'3.0'), True, 199),
#  ((u'{8f8fe09b-0bd3-4470-bc1b-8cad42b8203a}', u'0.17.1-signed.1-signed'),
#   False,
#   199),
#  ((u'{ad0d925d-88f8-47f1-85ea-8463569e756e}', u'2.0.5'), False, 199),
#  ((u'search@mail.ru', u'1.0.7'), False, 198),
#  ((u'status4evar@caligonstudios.com', u'2015.11.16.23.1-signed.1-let-fixed'),
#   True,
#   198),
#  ((u'vb@yandex.ru', u'2.29.1'), True, 198),
#  ((u'{0545b830-f0aa-4d7e-8820-50a4629a56fe}', u'31.0.7'), True, 198),
#  ((u'@testpilot-addon', u'0.8.5-tag-2016-09-12'), False, 196),
#  ((u'homepage@mail.ru', u'1.0.2'), False, 193),
#  ((u'savedpasswordeditor@daniel.dawson', u'2.10'), False, 193),
#  ((u'printedit@DW-dev', u'17.2'), False, 129),
#  ((u'tabcounter@morac', u'1.9.9.3'), False, 129),
#  ((u'mail.google.com@services.mozilla.org', u''), False, 128),
#  ((u'support@lastpass.com', u'4.1.28a'), False, 128),
#  ((u'firefox@zenmate.com', u'5.8.2'), True, 126),
#  ((u'public.proartex@gmail.com', u'1.1.2'), True, 126),
#  ((u'vdpure@link64', u'1.97.43'), True, 126),
#  ((u'{00000f2a-7cde-4f20-83ed-434fcb420d71}', u'0.9.8.45'), True, 125),
#  ((u'{02450914-cdd9-410f-b1da-db004e18c671}', u'0.99.04c'), True, 125),
#  ((u'vk@sergeykolosov.mp', u'0.3.9.5'), True, 124),
#  ((u'{455D905A-D37C-4643-A9E2-F6FEFAA0424A}', u'0.8.17.1-signed.1-signed'),
#   True,
#   124),
#  ((u'_65Members_@download.fromdoctopdf.com', u'7.38.8.56246'), True, 123),
#  ((u'jid0-UVAeBCfd34Kk5usS8A1CBiobvM8@jetpack', u'6.8.8.8'), False, 123),
#  ((u'newtabtools@darktrojan.net', u'73'), False, 123),
#  ((u'{6BB5760D-F97E-421B-AF5B-8457A90C3CED}', u'2.6.1'), True, 123),
#  ((u'jid1-AVgCeF1zoVzMjA@jetpack', u'0.9.5.5'), True, 122),
#  ((u'jid1-HAV2inXAnQPIeA@jetpack', u'1.6.3'), True, 122),
#  ((u'printedit@DW-dev', u'17.1'), False, 122),
#  ((u'jid1-P34HaABBBpOerQ@jetpack', u'0.2.1-signed.1-signed'), True, 121),
#  ((u'{54BB9F3F-07E5-486c-9B39-C7398B99391C}', u'5.0.2016031501'), False, 120),
#  ((u'{ea4637dc-e014-4c17-9c2c-879322d23268}', u'2.1.1-signed.1-signed'),
#   False,
#   120),
#  ((u'VimFx@akhodakivskiy.github.com', u'0.18.1'), False, 119),
#  ((u'{9AA46F4F-4DC7-4c06-97AF-5035170634FE}', u'10.25'), True, 119),
#  ((u'paulsaintuzb@gmail.com', u'8.2.1'), True, 118),
#  ((u'about-addons-memory@tn123.org', u'12'), False, 117),
#  ((u'clickclean@hotcleaner.com', u'4.1.1-signed.1-signed'), True, 117),
#  ((u'{c8d3bc80-0810-4d21-a2c2-be5f2b2832ac}', u'0.98'), True, 117),
#  ((u'87677a2c52b84ad3a151a4a72f5bd3c4@jetpack', u'8.689.572'), True, 116),
#  ((u'{9AA46F4F-4DC7-4c06-97AF-5035170634FE}', u'10.12'), False, 116),
#  ((u'openwith@darktrojan.net', u'6.7.2'), False, 113),
#  ((u'firebug@software.joehewitt.com', u'3.0.0-beta.3'), True, 112),
#  ((u'jid0-oFwt2ZcakHhkFl7Kp4lJn@jetpack', u'0.1.7'), True, 112),
#  ((u'extension@one-tab.com', u'1.17.0'), True, 111),
#  ((u'feedly@devhd', u'16.0.528.1-signed.1-signed'), True, 111),
#  ((u'jid1-KKzOGWgsW3Ao4Q@jetpack', u'2.5.9'), True, 111),
#  ((u'vwof@drev.com', u'3.1.2'), False, 110),
#  ((u'zoompage@DW-dev', u'15.1'), False, 109),
#  ((u'{53A03D43-5363-4669-8190-99061B2DEBA5}', u'1.5.14'), True, 109),
#  ((u'{a6fd85ed-e919-4a43-a5af-8da18bda539f}', u'2.9.1.1-signed'), True, 109),
#  ((u'firefoxaddon@youtubeenhancer.com', u'4.1.3'), True, 107),
#  ((u'xthunder@lshai.com', u'1.3.4.1-signed.1-signed'), True, 107),
#  ((u'fbt@quicksaver', u'2.1.10'), False, 106),
#  ((u'homeutil@yandex.ru', u'1.0.13'), False, 106),
#  ((u'wx-assistant@mozillaonline.com', u'2.0.1'), True, 106),
#  ((u'{068e178c-61a9-4a63-b74f-87404a6f5ea1}', u'2.0'), True, 106),
#  ((u'yasearch@yandex.ru', u'8.20.2'), True, 105),
#  ((u'ALone-live@ya.ru', u'1.4.11'), True, 104),
#  ((u'jid1-fRvgLzKONCsPew@jetpack', u'0.2.6'), False, 104),
#  ((u'mg.mail.yahoo.com@services.mozilla.org', u'1.0'), False, 104),
#  ((u'tineye@ideeinc.com', u'1.2.1'), False, 104),
#  ((u'{e4a8a97b-f2ed-450b-b12d-ee082ba24781}', u'3.8'), True, 104),
#  ((u'AdBlockerLavaSoftFF@lavasoft.com', u'1.1.4'), True, 103),
#  ((u'lazarus@interclue.com', u'2.3.1-signed.1-signed'), True, 102),
#  ((u'jid1-uqwEAwSca3FXUo@jetpack', u'0.2.1'), False, 100),
#  ((u'masspasswordreset@johnathan.nightingale', u'1.05.1-signed.1-signed'),
#   False,
#   100),
#  ((u'newtaboverride@agenedia.com', u'3.0'), False, 100),
#  ((u'omnibar@ajitk.com', u'0.7.28.20141004.1-signed.1-signed'), False, 100),
#  ((u'zoompage@DW-dev', u'15.2'), False, 100),
#  ((u'{11483926-db67-4190-91b1-ef20fcec5f33}', u'0.4.9.1'), False, 100),
#  ((u'{75CEEE46-9B64-46f8-94BF-54012DE155F0}', u'0.4.15'), True, 100),
#  ((u'jid1-i6dUGvCrz2WZu8@jetpack', u'0.1.7'), True, 99),
#  ((u'jid1-mdjmA7if6lo8lA@jetpack', u'0.7.1-signed.1-signed'), True, 99),
#  ((u'jid1-w4wG5nJhx4LJZr@jetpack', u'0.1.3'), False, 99),
#  ((u'{b749fc7c-e949-447f-926c-3f4eed6accfe}', u'0.7.1.1.1-signed.1-signed'),
#   False,
#   99),
#  ((u'ClassicThemeRestorer@ArisT2Noia4dev', u'1.5.6beta6'), False, 98),
#  ((u'html5-video-everywhere@lejenome.me', u'0.3.4'), True, 98),
#  ((u'save-as-pdf-ff@pdfcrowd.com', u'1.5.1-signed.1-signed'), True, 98),
#  ((u'{4093c4de-454a-4329-8aff-c6b0b123c386}', u'0.8.14.1-signed.1-signed'),
#   False,
#   98),
#  ((u'{dd3d7613-0246-469d-bc65-2a3cc1668adc}', u'1.1.8.1-signed.1-signed'),
#   True,
#   97),
#  ((u'{02450914-cdd9-410f-b1da-db004e18c671}', u'0.99.05c'), True, 96),
#  ((u'{66E978CD-981F-47DF-AC42-E3CF417C1467}', u'0.5.2'), True, 96),
#  ((u'{73007fef-a6e0-47d3-b4e7-dfc116ed6f65}', u'1.15.1-signed.1-signed'),
#   False,
#   95),
#  ((u'colorPicker@colorPicker', u'3.0.1-signed.1-signed'), True, 94),
#  ((u'cpmanager@mozillaonline.com', u'2.48'), True, 94),
#  ((u'fvdmedia@gmail.com', u'10.6.1'), False, 94),
#  ((u'jid1-dwtFBkQjb3SIQp@jetpack', u'0.3.4'), True, 94),
#  ((u'{195A3098-0BD5-4e90-AE22-BA1C540AFD1E}', u'4.1.0.1-signed.1-signed'),
#   False,
#   94),
#  ((u'{4cc4a13b-94a6-7568-370d-5f9de54a9c7f}', u'2.7.1-signed.1-signed'),
#   False,
#   94),
#  ((u'{ce7e73df-6a44-4028-8079-5927a588c948}', u'1.1.2.1-signed.1-signed'),
#   True,
#   94),
#  ((u'dta3noaero@vano', u'1.0.1'), False, 93),
#  ((u'gmailnoads@mywebber.com', u'5.0.1'), True, 93),
#  ((u'uBlock0@raymondhill.net', u'1.9.7b1'), False, 93),
#  ((u'{02450914-cdd9-410f-b1da-db004e18c671}', u'0.99.06c'), True, 93),
#  ((u'firefox@browser-security.de', u'1.2.0'), False, 92),
#  ((u'jid1-wZqm19rJzRkZUA@jetpack', u'0.1.9'), False, 92),
#  ((u'coba@mozilla.com.cn', u'1.0.32'), True, 91),
#  ((u'homepage@mail.ru', u'1.0.3'), False, 91),
#  ((u'jid1-OoNOA6XBjznvLQ@jetpack', u'1.9.7'), True, 90),
#  ((u'jid1-kps5PrGBNtzSLQ@jetpack', u'0.2.2'), False, 90),
#  ((u'particle@particlecore.github.io', u'1.5.0'), True, 90),
#  ((u'restartless.restart@erikvold.com', u'9.1-signed.1-signed'), False, 90),
#  ((u'tiletabs@DW-dev', u'14.3'), False, 89),
#  ((u'{0AA9101C-D3C1-4129-A9B7-D778C6A17F82}', u'2.09.1-signed'), True, 89),
#  ((u'{4a313247-8330-4a81-948e-b79936516f78}', u'2.0.3.1-signed'), False, 89),
#  ((u'jid0-dsq67mf5kjjhiiju2dfb6kk8dfw@jetpack', u'0.3.0'), False, 88),
#  ((u'jid1-hDf2iQXGiUjzGQ@jetpack', u'2.3.0'), True, 88),
#  ((u'proxyselector@mozilla.org', u'1.31.1-signed.1-signed'), True, 88),
#  ((u'{37fa1426-b82d-11db-8314-0800200c9a66}', u'3.5.23'), True, 88),
#  ((u'{a38384b3-2d1d-4f36-bc22-0f7ae402bcd7}', u'1.0.0.52'), False, 88),
#  ((u'places-maintenance@bonardo.net', u'2.0.2'), False, 87),
#  ((u'qwantcomforfirefox@jetpack', u'3.0.19'), True, 87),
#  ((u'search@mail.ru', u'1.0.8'), False, 87),
#  ((u'WebProtection@360safe.com', u'5.0.0.1005'), False, 86),
#  ((u'jid0-SQnwtgW1b8BsMB5PLV5WScEDWOjw@jetpack', u'3.9.1'), False, 86),
#  ((u'wappalyzer@crunchlabz.com', u'3.2.7'), True, 86),
#  ((u'{0e3fc079-afbb-4a00-87e5-9486062d0f9c}', u'0.1.7.1-signed.1-signed'),
#   False,
#   69),
#  ((u'{D9A7CBEC-DE1A-444f-A092-844461596C4D}', u'7.7'), False, 69),
#  ((u'cam@sdrocking.com', u'7.1'), False, 68),
#  ((u'enhancerforyoutube@maximerf.addons.mozilla.org', u'2.0.14'), False, 68),
#  ((u'helper-sig@savefrom.net', u'6.57'), True, 68),
#  ((u'rikaichan-jpnames@polarcloud.com', u'2.01.160101'), False, 68),
#  ((u'wappalyzer@crunchlabz.com', u'3.2.5'), True, 68),
#  ((u'@90B817C8-8A5C-413B-9DDD-B2C61ED6E79A', u'1.09'), True, 67),
#  ((u'dave@tails.boum.org', u'0.2.7rc55'), False, 67),
#  ((u'jid1-AQqSMBYb0a8ADg@jetpack', u'1.5.1'), False, 67),
#  ((u'wrc@avast.com', u'10.3.3.39'), True, 67),
#  ((u'zotero@chnm.gmu.edu', u'4.0.29.11'), False, 67),
#  ((u'{7f57cf46-4467-4c2d-adfa-0cba7c507e54}', u'4.0.1rc'), True, 67),
#  ((u'{EF522540-89F5-46b9-B6FE-1829E2B572C6}', u'8.8'), False, 67),
#  ((u'CSTBB@NArisT2_Noia4dev', u'1.5.2.2'), False, 66),
#  ((u'FasterFox_Lite@BigRedBrent', u'3.9.9Lite.1-signed.1-signed'), False, 66),
#  ((u'amcontextmenu@loucypher', u'0.4.2.1-signed.1-signed'), True, 66),
#  ((u'imageblock@hemantvats.com', u'3.1'), True, 66),
#  ((u'particle@particlecore.github.io', u'1.5.1'), False, 66),
#  ((u'rest-easy@quickmediasolutions.com', u'0.3.1.1-signed'), False, 66),
#  ((u'vb@yandex.ru', u'2.27.1'), True, 66),
#  ((u'{176c8b66-7fc3-4af5-a86b-d0207c456b14}', u'1.0'), True, 66),
#  ((u'{c6448328-31f7-4b12-a2e0-5c39d0290307}', u'3.4.1-signed.1-signed'),
#   False,
#   66),
#  ((u'nimbusscreencaptureff@everhelper.me', u'8.5.3'), True, 65),
#  ((u'{D4DD63FA-01E4-46a7-B6B1-EDAB7D6AD389}', u'0.9.10.1-signed.1-signed'),
#   True,
#   65),
#  ((u'{cd617372-6743-4ee4-bac4-fbf60f35719e}', u'2.0.1-signed.1-signed'),
#   True,
#   65),
#  ((u'FavIconReloader@mozilla.org', u'0.8.1-signed'), False, 64),
#  ((u'UIEnhancer@girishsharma', u'5.3'), True, 64),
#  ((u'firefox@tampermonkey.net', u'4.1.5259'), False, 64),
#  ((u'gmailnoads@mywebber.com', u'5.0'), True, 64),
#  ((u'nishan.naseer.googimagesearch@gmail.com', u'0.5.1-signed.1-signed'),
#   True,
#   64),
#  ((u'{5F590AA2-1221-4113-A6F4-A4BB62414FAC}',
#    u'0.45.8.20130519.3.1-signed.1-signed'),
#   True,
#   64),
#  ((u'{987311C6-B504-4aa2-90BF-60CC49808D42}', u'3.1-signed.1-signed'),
#   False,
#   64),
#  ((u'{f69e22c7-bc50-414a-9269-0f5c344cd94c}', u'48.4'), False, 64),
#  ((u'bookmarkdeduplicator@foxhatdev', u'1.3.1.1-signed.1-signed'), False, 63),
#  ((u'jid1-AQqSMBYb0a8ADg@jetpack', u'1.5.2'), False, 63),
#  ((u'multilinksplus@hugsmile.eu', u'3.6.6'), True, 63),
#  ((u'uBlock0@raymondhill.net', u'1.9.5b2'), False, 63),
#  ((u'universal-search@mozilla.com', u'1.0.9'), False, 63),
#  ((u'yslow@yahoo-inc.com', u'3.1.8.1-signed.1-signed'), True, 63),
#  ((u'cookiemgr@jayapal.com', u'5.12'), False, 62),
#  ((u'jsdeobfuscator@adblockplus.org', u'2.0.3'), False, 62),
#  ((u'stefanvandamme@stefanvd.net', u'3.2.0.16'), False, 62),
#  ((u'{210249CE-F888-11DD-B868-4CB456D89593}', u'4.1.1'), False, 62),
#  ((u'abhere2@moztw.org', u'48.0.20160817'), False, 61),
#  ((u'osb@quicksaver', u'1.6.13'), False, 61),
#  ((u'smarterwiki@wikiatic.com', u'5.2.1.1-signed.1-signed'), False, 61),
#  ((u'stefanvandamme@stefanvd.net', u'3.2.0.15'), False, 61),
#  ((u'universal-search@mozilla.com', u'1.0.8'), False, 61),
#  ((u'{45d8ff86-d909-11db-9705-005056c00008}', u'1.3.0.5'), False, 61),
#  ((u'{8b86149f-01fb-4842-9dd8-4d7eb02fd055}', u'0.26.1-signed.1-signed'),
#   True,
#   61),
#  ((u'adonis.cuhk@gmail.com', u'1.8.9.1-signed.1-signed'), False, 60),
#  ((u'googletestNT@mozillaonline.com', u'0.10.43'), False, 60),
#  ((u'jid1-sNL73VCI4UB0Fw@jetpack', u'2.1.4'), True, 60),
#  ((u'{891f0410-aaa2-11e0-9f1c-0800200c9a66}', u'2.15'), False, 60),
#  ((u'clipconverter@clipconverter.cc', u'1.5.2'), True, 59),
#  ((u'formhistory@yahoo.com', u'1.4.0.6'), True, 59),
#  ((u'jid1-YdiFiTEkQgInxA@jetpack', u'7.3'), True, 59),
#  ((u'readable@evernote.com', u'10.2.1.7.1-signed'), True, 59),
#  ((u'tinyjsdebugger@enigmail.net', u'1.1.5'), False, 59),
#  ((u'{77b819fa-95ad-4f2c-ac7c-486b356188a9}',
#    u'4.0.20130422.1-signed.1-signed'),
#   True,
#   59),
#  ((u'{AE93811A-5C9A-4d34-8462-F7B864FC4696}', u'4.21'), False, 59),
#  ((u'{EF522540-89F5-46b9-B6FE-1829E2B572C6}', u'8.9'), False, 59),
#  ((u'{e4a8a97b-f2ed-450b-b12d-ee082ba24781}', u'3.9beta2'), False, 59),
#  ((u'{f13b157f-b174-47e7-a34d-4815ddfdfeb8}', u'0.9.89.1-signed.1-signed'),
#   False,
#   59),
#  ((u'CanvasBlocker@kkapsner.de', u'0.3.1-Release'), False, 58),
#  ((u'ClickToPlayPerElement@uaSad.addons.mozilla.org', u'0.3.3'), False, 58),
#  ((u'NoiaScrollbars@ArisT2_Noia4dev', u'1.2.5.1'), False, 58),
#  ((u'search4baidu@baidu.com', u'1.0.5.1-signed.1-signed'), False, 58),
#  ((u'{3e9a3920-1b27-11da-8cd6-0800200c9a66}', u'3.11'), False, 58),
#  ((u'caa1-aDOiCAxFFMOVIX@jetpack', u'0.1.7'), True, 57),
#  ((u'restartbutton@strk.jp', u'0.1.5.1-signed.1-signed'), False, 57),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.0a10'), False, 57),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.1a4'), False, 57),
#  ((u'{d48a39ba-8f80-4fce-8ee1-bc710561c55d}', u'3.1.0.1-signed.1-signed'),
#   False,
#   57),
#  ((u'{daf44bf7-a45e-4450-979c-91cf07434c3d}', u'2.0.5'), False, 57),
#  ((u'ClassicThemeRestorer@ArisT2Noia4dev', u'1.5.7beta2'), False, 56),
#  ((u'LDSI_plashcor@gmail.com', u'1.1.0.3'), True, 56),
#  ((u'dta@downthemall.net', u'3.0.1.20160901.00h01m31s'), False, 56),
#  ((u'vlcplaylist@helgatauscher.de', u'0.8.1-signed.1-signed'), False, 56),
#  ((u'DailymotionVideoDownloader@PeterOlayev.com', u'1.0.6.1-signed.1-signed'),
#   True,
#   55),
#  ((u'VacuumPlacesImproved@lultimouomo-gmail.com', u'1.2.1-signed.1-signed'),
#   False,
#   55),
#  ((u'copyplaintext@teo.pl', u'1.6'), False, 55),
#  ((u'dta@downthemall.net', u'3.0.1.20160831.00h01m33s'), False, 55),
#  ((u'jid0-edalmuivkozlouyij0lpdx548bc@jetpack', u'1.16.22'), True, 55),
#  ((u'quicksearch@yandex.ru', u'1.0.13'), False, 55),
#  ((u'{54e46280-0211-11e3-b778-0800200c9a66}', u'0.2'), False, 55),
#  ((u'DuplicateInTabContext@schuzak.jp', u'1.0.11'), False, 54),
#  ((u'LVD-SAE@iacsearchandmedia.com', u'8.5'), True, 54),
#  ((u'avg@toolbar', u'4.3.4.122'), False, 54),
#  ((u'dta@downthemall.net', u'3.0.5.20160905.00h00m59s'), False, 54),
#  ((u'openbookmarkintab@piro.sakura.ne.jp', u'2.0.2016021001'), False, 54),
#  ((u'ramback@pavlov.net', u'1.0.1-signed.1-signed'), False, 54),
#  ((u'{a95d8332-e4b4-6e7f-98ac-20b733364387}', u'1.0.5'), True, 54),
#  ((u'{b1df372d-8b32-4c7d-b6b4-9c5b78cf6fb1}', u'0.87.1-signed.1-signed'),
#   True,
#   54),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.1a1'), False, 54),
#  ((u'{f36c6cd1-da73-491d-b290-8fc9115bfa55}',
#    u'3.0.9.1-signed.1-let-fixed.1-signed'),
#   True,
#   54),
#  ((u'@DownloadManager', u'0.2.1'), True, 53),
#  ((u'_ceMembers_@free.easypdfcombine.com', u'7.38.8.46224'), True, 53),
#  ((u'jid0-RwTySlpoKU14fw7yw2AflOAihhA@jetpack', u'2.0.4'), False, 53),
#  ((u'jid1-D7momAzRw417Ag@jetpack', u'4.5.13'), True, 53),
#  ((u'jid1-wkCmfgboni3B1Q@jetpack', u'1.5.0'), True, 53),
#  ((u'openlinkintab@piro.sakura.ne.jp', u'1.0.2016011401'), False, 53),
#  ((u'{f3bd3dd2-2888-44c5-91a2-2caeb33fb898}', u'48.2'), True, 53),
#  ((u'FireXPath@pierre.tholence.com', u'0.9.7.1.1-signed.1-signed'), False, 52),
#  ((u'autofillForms@blueimp.net', u'1.1.4'), True, 52),
#  ((u'cliqz@cliqz.com', u'2.8.2'), False, 52),
#  ((u's3menu@wizard', u'5.01'), True, 52),
#  ((u'{4DC70064-89E2-4a55-8FC6-E8CDEAE3618C}', u'0.7.7.1-signed.1-signed'),
#   True,
#   52),
#  ((u'dta@downthemall.net', u'3.0.3.20160902.00h00m35s'), False, 51),
#  ((u'printPages2Pdf@reinhold.ripper', u'0.1.9.3.1-signed'), True, 51),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.18.2016090601'), False, 51),
#  ((u'{e8deb9e5-5688-4655-838a-b7a121a9f16e}', u'48.2'), True, 51),
#  ((u'customization@adblockplus.org', u'1.0.5'), False, 50),
#  ((u'firequery@binaryage.com', u'2.0.4'), True, 50),
#  ((u'quicklaunch@mozillaonline.com', u'1.1.7'), False, 50),
#  ((u'uBlock0@raymondhill.net', u'1.9.5b3'), False, 50),
#  ((u'unplug@compunach', u'2.059'), False, 50),
#  ((u'yetanothersmoothscrolling@kataho', u'3.2.6'), False, 50),
#  ((u'{146f1820-2b0d-49ef-acbf-d85a6986e10c}', u'0.1.9.3.1-signed.1-signed'),
#   True,
#   50),
#  ((u'{22119944-ED35-4ab1-910B-E619EA06A115}', u'7.9.21.1'), False, 50),
#  ((u'{22870005-adef-4c9d-ae36-d0e1f2f27e5a}', u'0.4.0.9.1.1-signed.1-signed'),
#   True,
#   50),
#  ((u'{ac2cfa60-bc96-11e0-962b-0800200c9a66}', u'5.5'), False, 50),
#  ((u'{ea61041c-1e22-4400-99a0-aea461e69d04}', u'0.2.4.1-signed.1-signed'),
#   True,
#   50)]

# %% [markdown]
# ### CPOWs

# %% [markdown]
# CPOW usage is recorded in the `PERF_MONITORING_SLOW_ADDON_CPOW_US` histogram as time in microseconds spent by an add-on blocking the main loop using a CPOW.
#
# Summarize CPOW usage for each enabled add-on (ID and version) by:
#
# - average number of microseconds per CPOW blocking occurrence
# - average number of blocking occurrences per hour of session time
#
# Note that in many cases an add-on has an entry in the histogram, but it only has observations with the value 0. It appears that the histogram is automatically recorded at the same time as `PERF_MONITORING_SLOW_ADDON_JANK_US` by the [AddonWatcher](https://dxr.mozilla.org/mozilla-central/source/toolkit/components/perfmonitoring/AddonWatcher.jsm#128), and so may not have any CPOW blocking to report at that time. This is handled by dropping observations in the histograms' '0' bucket.

# %%
## Summarize CPOW usage per add-on, returning entries of the form
## ((GUID, version), { 
##    "totalTime" : <total session time in seconds with this add-on>,
##    "numOccurrences": <total number of times add-on CPOW blocked main loop>,
##    "totalCPOWTime": <total blocking time for add-on CPOWs>
## })

def getCPOWData(d):
    """ Summarize CPOW data for each add-on/session as a list of
            ((GUID, version), {totalTime, numOccurrences, totalCPOWTime}).
    """
    result = []
    for addonv in d["addons"]:
        data = {
            "totalTime": d["sessionLength"],
            "numOccurrences": 0,
            "totalCPOWTime": 0
        }
        cpowData = d["cpowTime"].get(addonv[0])
        
        ## If the histogram is present, but all values are 0, ignore it completely.
        if cpowData and cpowData["sum"] > 0:
            ## Some of the CPOW values may be 0 - ignore those.
            data["numOccurrences"] = sum([n for v, n in cpowData["values"].items() if v != "0"])
            data["totalCPOWTime"] = cpowData["sum"]
        result.append((addonv, data))
    return result

def dictSum(a, b):
    """ Add up like entries between two dicts. """
    result = {}
    for k in a:
        result[k] = a[k] + b[k]
    return result

cpowBySession = bySession.flatMap(getCPOWData).reduceByKey(dictSum)

# %% [markdown]
# Our final CPOW dataset is restricted to add-ons which were active during a total accumulated session time of at least 1 hour.

# %%
cpowFiltered = cpowBySession.filter(lambda (addon, data): data["totalTime"] >= 3600)

# %%
## Summarize add-on CPOW usage with:
## - hadCPOWBlocking: were there any CPOW blocking occurrences?
## - avgBlockingTime: the average blocking time spent per occurrence (truncated to the nearest microsecond)
## - occurrenceFreq: the average number of blocking occurrences per session hour.

def summaryCPOWTime(d):
    sessionHours = float(d["totalTime"]) / 3600
    hadCPOWBlocking = d["numOccurrences"] > 0
    return {
        "hadCPOWBlocking": hadCPOWBlocking,
        ## Since these are microseconds anyway, truncate using integer division.
        "avgBlockingTime": d["totalCPOWTime"] / d["numOccurrences"] if hadCPOWBlocking else 0,
        "occurrenceFreq": float(d["numOccurrences"]) / sessionHours if hadCPOWBlocking else 0
    }

cpowSummary = cpowFiltered.mapValues(summaryCPOWTime)

# %% [markdown]
# How many add-ons were active during at least 1 hour of overall session time?

# %%
cpowFiltered.count()
# Out:
# 8327

# %% [markdown]
# How many of these had blocking CPOWs?

# %%
cpowHadBlocking = cpowSummary.filter(lambda (addon, summary): summary["hadCPOWBlocking"]).collect()
len(cpowHadBlocking)
# Out:
# 2044

# %% [markdown]
# Dump data for add-ons that had CPOW blocking to a JSON file that will be used in the HTML page.
#
# The file is one big JSON array with elements of the form `[[<GUID>, <version>], <avgBlockingTime>, <occurrenceFreq>]`.

# %%
def formatForJSON((addon, summary)):
    return (addon, summary["avgBlockingTime"], summary["occurrenceFreq"])

## Order by decreasing average blocking time.
cpowBlockingOutput = map(formatForJSON, cpowHadBlocking)
cpowBlockingOutput.sort(key = lambda (addon, avg, freq): -avg)


try:
    output = open('output/cpow-data.json', 'w')
    json.dump(cpowBlockingOutput, output)
    output.close()
except:
    pass

try:
    output = open('cpow-data.json', 'w')
    json.dump(cpowBlockingOutput, output)
    output.close()
except:
    pass

# %% [markdown]
# The blocking CPOW data, ordered by decreasing average blocking time.

# %%
sorted(cpowHadBlocking, key = lambda (addon, summary): summary["avgBlockingTime"], reverse = True)
# Out:
# [((u'{e98b7313-167d-48c6-89be-bc514d6de8d9}', u'4.5.1-signed.1-signed'),
#   {'avgBlockingTime': 31630591,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.013292155002937402}),
#  ((u'{53A03D43-5363-4669-8190-99061B2DEBA5}', u'1.5.13'),
#   {'avgBlockingTime': 17252625,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.030683369784040217}),
#  ((u'{1BFCBDFC-41DB-11E1-9FC4-D3C94824019B}', u'3.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 7405952,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40710059171597635}),
#  ((u'cacaoweb@cacaoweb.org', u'1.0.34'),
#   {'avgBlockingTime': 6961773,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.1194925549499791}),
#  ((u'mweb71@yahoo.com', u'2.0.1-signed.1-signed'),
#   {'avgBlockingTime': 5977808,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.025503914850929617}),
#  ((u'ascsurfingprotectionnew@iobit.com', u'2.1.2'),
#   {'avgBlockingTime': 5043876,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9085838396695611}),
#  ((u'{53A03D43-5363-4669-8190-99061B2DEBA5}', u'1.5.13.1-signed.1-signed'),
#   {'avgBlockingTime': 3529286,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.09300277660463487}),
#  ((u'{888d99e7-e8b5-46a3-851e-1ec45da1e644}', u'45.0.0'),
#   {'avgBlockingTime': 3019518L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.21626386335450473}),
#  ((u'_dgMembers_@free.trackapackage.net', u'7.102.10.4997'),
#   {'avgBlockingTime': 2987698,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.05059946308347506}),
#  ((u'{53A03D43-5363-4669-8190-99061B2DEBA5}', u'1.5.14'),
#   {'avgBlockingTime': 2881024,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.020524205564619855}),
#  ((u'listit@csail.mit.edu', u'0.5.0.2.1-signed.1-let-fixed.1-signed'),
#   {'avgBlockingTime': 2586626,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9599589153386028}),
#  ((u'usablehomebutton@tanalin.com', u'1.4.1'),
#   {'avgBlockingTime': 2347246,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.230385198962361}),
#  ((u'sdtools@sharedir.com', u'1.6.0'),
#   {'avgBlockingTime': 2323970,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4204420480977917}),
#  ((u'toolbar@boounce.com', u'0.6.1-signed.1-signed'),
#   {'avgBlockingTime': 2230503,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.20170327207530256}),
#  ((u'support@lastpass.com', u'3.2.21'),
#   {'avgBlockingTime': 2161831,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.04669644285522805}),
#  ((u'{FF20459C-DA6E-41A7-80BC-8F4FEFD9C575}', u'2.0.0.9'),
#   {'avgBlockingTime': 2039499,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.039598208728459}),
#  ((u'a000b6@wips.com', u'1.0.5.1-signed.1-signed'),
#   {'avgBlockingTime': 1893605,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.057124333832793445}),
#  ((u'{a7c6cf7f-112c-4500-a7ea-39801a327e5f}', u'2.0.28'),
#   {'avgBlockingTime': 1818666,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.005663108968371022}),
#  ((u'4or6@hunen.net', u'1.2.1.1-signed'),
#   {'avgBlockingTime': 1810044,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.020465999437185016}),
#  ((u'furiganainserter@zorkzero.net', u'13'),
#   {'avgBlockingTime': 1796634,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.28306765498407743}),
#  ((u'{d09e32df-8610-4b33-b929-1e631b764130}', u'0.5.0.1-signed.1-signed'),
#   {'avgBlockingTime': 1736357,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.15803292901413243}),
#  ((u'tranquility@ushnisha.com', u'1.2.1-signed'),
#   {'avgBlockingTime': 1556633,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.07169661302442511}),
#  ((u'freeconetmanager@ff.banasiak.net', u'0.9.8.1-signed.1-signed'),
#   {'avgBlockingTime': 1530168,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.771454991642067}),
#  ((u'{b2509cd4-17cd-45ed-8146-a82af038f493}', u'2.02.1-signed.1-signed'),
#   {'avgBlockingTime': 1520157,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 9.535672100457866}),
#  ((u'tabletools2@mingyi.org', u'1.17.1-signed.1-signed'),
#   {'avgBlockingTime': 1473784,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.37929225251630555}),
#  ((u'amznUWL2@amazon.com', u'1.11'),
#   {'avgBlockingTime': 1443377,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.4372647133136875}),
#  ((u'firefox1@myibay.com', u'1.3.7.1-signed.1-signed'),
#   {'avgBlockingTime': 1424852,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.8067404136636978}),
#  ((u'_frMembers_@free.testforspeed.com', u'7.38.8.45923'),
#   {'avgBlockingTime': 1318672,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9305880237367379}),
#  ((u'{99392FC6-2524-D2F9-19D8-D4C27B7518F6}', u'3.0.3'),
#   {'avgBlockingTime': 1287018,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2932355105876056}),
#  ((u'googleviewer@brandon.siegel', u'1.1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 1148753,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.824071175695158}),
#  ((u'{02450914-cdd9-410f-b1da-db004e18c671}', u'0.99.06c'),
#   {'avgBlockingTime': 1030473,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.042863937704410535}),
#  ((u'accessext@cita.uiuc.edu', u'1.5.7.1.1-signed.1-signed'),
#   {'avgBlockingTime': 1005748,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.25397900440230275}),
#  ((u'extended@fremea', u'1.4.2.1-signed.1-signed'),
#   {'avgBlockingTime': 1000643,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0040452483501566975}),
#  ((u'{F71E8E3B-94EA-0F15-76E9-F1F427DCA73A}', u'1.186'),
#   {'avgBlockingTime': 980430L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 571.7507077913169}),
#  ((u'shumway-dev@research.mozilla.org', u'0.11.622'),
#   {'avgBlockingTime': 972478,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.04286065079731228}),
#  ((u'{0A558D49-3BB2-42e2-A53B-257CC7AE7C08}', u'2.4'),
#   {'avgBlockingTime': 969547,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.861228674664094}),
#  ((u'amznUWL2@amazon.com', u'1.10.1-signed.1-signed'),
#   {'avgBlockingTime': 922724,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.7083897364912316}),
#  ((u'amznUWL2@amazon.com', u'1.10.1-signed'),
#   {'avgBlockingTime': 910735,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.427781180969352}),
#  ((u'foxmarks@kei.com', u'4.3.7.1-signed'),
#   {'avgBlockingTime': 877097,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.1446654611211573}),
#  ((u'ImagePicker@topolog.org', u'1.9.4'),
#   {'avgBlockingTime': 876997,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.8111096483371119}),
#  ((u'fancy.firefox@thingd.com', u'0.3.312122.1-signed.1-signed'),
#   {'avgBlockingTime': 875551,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5327709639824629}),
#  ((u'manish.p05@gmail.com', u'12.9'),
#   {'avgBlockingTime': 874237,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.04319281456677671}),
#  ((u'{22119944-ED35-4ab1-910B-E619EA06A115}', u'7.9.16.9'),
#   {'avgBlockingTime': 871015,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.11675629776393999}),
#  ((u'_d1Members_@free.mysocialshortcut.com', u'7.38.8.46549'),
#   {'avgBlockingTime': 858238,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.19688807459870383}),
#  ((u'jyboy.yy@gmail.com', u'1.0.4.1-signed.1-signed'),
#   {'avgBlockingTime': 851032,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.011257774900790858}),
#  ((u'jid1-tDEBR70q2oOOTw@jetpack', u'2.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 825143,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.048222313036371}),
#  ((u'{7cad0727-da80-44e6-ab41-2fe3875883fe}', u'8.8.0'),
#   {'avgBlockingTime': 820018,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.03659568628347934}),
#  ((u'docview@mozilla.org', u'2.3.1-signed.1-signed'),
#   {'avgBlockingTime': 814524,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 73.56553822866242}),
#  ((u'spelltab@yigotech.com', u'1.3.1-signed.1-signed'),
#   {'avgBlockingTime': 809601,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.09472437837126693}),
#  ((u'peraperakun@gmail.com', u'12.1.3.0'),
#   {'avgBlockingTime': 808765,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.1046749799692421}),
#  ((u'gvoice@elijahclark.com', u'5.2.1-signed.1-signed'),
#   {'avgBlockingTime': 806129,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 76.32099124075607}),
#  ((u'{72CA2996-F580-47DF-98FF-0B853D09CEC8}', u'7.0.4.8'),
#   {'avgBlockingTime': 784114,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 87.57307184612483}),
#  ((u'oktools.ru@mail.ru', u'2.8.2.1-signed.1-signed'),
#   {'avgBlockingTime': 782078,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.5138333043326953}),
#  ((u'craigslistfusion@craigslistfusion.com', u'9.9.50'),
#   {'avgBlockingTime': 778885,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.211894056993027}),
#  ((u'{6E727987-C8EA-44DA-8749-310C0FBE3C3E}', u'1.0.0.66'),
#   {'avgBlockingTime': 768351,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.4435106178225445}),
#  ((u'{22119944-ED35-4ab1-910B-E619EA06A115}', u'7.9.21.5'),
#   {'avgBlockingTime': 763699,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0111694317474033}),
#  ((u'toolbar@sape.ru', u'2.35.2'),
#   {'avgBlockingTime': 757560,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.527747687692692}),
#  ((u'{e8deb9e5-5688-4655-838a-b7a121a9f16e}', u'48.1'),
#   {'avgBlockingTime': 732332,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4452179112126583}),
#  ((u'hupper@ajnasz.hu', u'1.5.1-signed.1-signed'),
#   {'avgBlockingTime': 725389,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.8916776750330251}),
#  ((u'{f36c6cd1-da73-491d-b290-8fc9115bfa55}',
#    u'3.0.9.1-signed.1-let-fixed.1-signed'),
#   {'avgBlockingTime': 712082L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.34194986620687}),
#  ((u'joomla-admin@mozilla.org', u'1.6.1-signed.1-signed'),
#   {'avgBlockingTime': 687438,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.23717059639389734}),
#  ((u'{47F7DAA8-DB46-4FE2-87B0-C6D7C8DD2F23}', u'0.4.1-signed.1-signed'),
#   {'avgBlockingTime': 667958,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.08634658024901927}),
#  ((u'none@allvideodownloader.com', u'2.6.0.1-signed'),
#   {'avgBlockingTime': 652234L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 262.48014896145287}),
#  ((u'abc@def.net', u'0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 643169,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.1935686062445847}),
#  ((u'megadebridplugin@mega-debrid.eu', u'1.8.31'),
#   {'avgBlockingTime': 627690,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.013009042006919365}),
#  ((u'{458482f0-90fb-4257-855f-0ba2790584f9}', u'7.9'),
#   {'avgBlockingTime': 624552,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.74922282251876}),
#  ((u'searchyoutube@searchyoutube.fr', u'1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 613700,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.31475082226570633}),
#  ((u'{62b958b4-9962-4fc2-9983-01a9a42d6f2d}', u'0.4.2.1-signed.1-signed'),
#   {'avgBlockingTime': 610435,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.30005425935974}),
#  ((u'_4jMembers_@www.radiorage.com', u'7.38.8.45249'),
#   {'avgBlockingTime': 610174,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.17320801529031}),
#  ((u'neoedmund@gmail.com', u'2.160420.1'),
#   {'avgBlockingTime': 599634,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9785428241364524}),
#  ((u'firefox@openattribute.com', u'0.9.8.1-signed.1-signed'),
#   {'avgBlockingTime': 591684,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.17822664488341008}),
#  ((u'jid1-Ng3EPAgCGPBsKA@jetpack', u'1.1.10'),
#   {'avgBlockingTime': 590474,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.844494587862066}),
#  ((u'{85E85FF9-E50C-42DE-8A3D-61485FD6C8DB}', u'2.0'),
#   {'avgBlockingTime': 590227,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.06217643426785089}),
#  ((u'{281944CE-E7F4-4A43-A5D0-EAC0B3E71BFF}', u'1.0.3.1-signed.1-signed'),
#   {'avgBlockingTime': 588555,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5853812606952346}),
#  ((u'{0e10f3d7-07f6-4f12-97b9-9b27e07139a5}', u'1.10.3'),
#   {'avgBlockingTime': 418091,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.073323591845101}),
#  ((u'fbsidebardisabler@vittgam.net', u'4.4.9'),
#   {'avgBlockingTime': 414398,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.3143170002663536}),
#  ((u'{da8bd68d-8e90-41cd-8345-a71b294e72e6}', u'2.0.18.2'),
#   {'avgBlockingTime': 411569,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.023214174402933583}),
#  ((u'hacktheweb@instantfox.com', u'1.3.20.1-signed.1-signed'),
#   {'avgBlockingTime': 404696,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.018454606154354836}),
#  ((u'{cd617375-6743-4ee8-bac4-fbf10f35729e}', u'2.9.6'),
#   {'avgBlockingTime': 402243,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.0162063994112858}),
#  ((u'SciLorsGrooveUnlocker@scilor.com', u'0.3.3.1-signed.1-signed'),
#   {'avgBlockingTime': 398323,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.015798412259567914}),
#  ((u'MPS@MyPoints.com', u'121'),
#   {'avgBlockingTime': 396577,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.326993718196418}),
#  ((u'vdpure@link64', u'1.97.43'),
#   {'avgBlockingTime': 396538,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.4384901335274616}),
#  ((u'{3E5EE13F-9517-4DDF-BABF-83303B9AB98F}', u'1.26.1-signed.1-signed'),
#   {'avgBlockingTime': 396235,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.98580548705567}),
#  ((u'vdpure@link64', u'1.97.42'),
#   {'avgBlockingTime': 395732,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.965780851838369}),
#  ((u'firefox-autofill@googlegroups.com', u'3.6'),
#   {'avgBlockingTime': 391364,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.6768483165567512}),
#  ((u'{CB454AEB-2F60-4441-ADEB-2CB43BB33B20}', u'3.0.1-signed.1-signed'),
#   {'avgBlockingTime': 390049,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.17398553745219927}),
#  ((u'inspectcontext@max.max', u'1.00.1-signed.1-signed'),
#   {'avgBlockingTime': 383842,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.006142111832927734}),
#  ((u'{4176DFF4-4698-11DE-BEEB-45DA55D89593}', u'0.8.50.1-signed.1-signed'),
#   {'avgBlockingTime': 380922,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9376826180894446}),
#  ((u'bartab-plus.firefox@moltendorf.net', u'3.2.8'),
#   {'avgBlockingTime': 379811,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.11041516100538022}),
#  ((u'{FFA36170-80B1-4535-B0E3-A4569E497DD0}', u'3.2pre.20120202'),
#   {'avgBlockingTime': 379558,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.714151883964003}),
#  ((u'{a6fd85ed-e919-4a43-a5af-8da18bda539f}', u'2.9.1.1-signed'),
#   {'avgBlockingTime': 375510,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5414179063217945}),
#  ((u'show-anchors-2@stefanheule.com', u'1.12.1-signed.1-signed'),
#   {'avgBlockingTime': 374277,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4988480168102682}),
#  ((u'{31C8B8A4-6712-4A47-B378-2BE78B8EE9E1}', u'3.11.9'),
#   {'avgBlockingTime': 373297,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.854297884734408}),
#  ((u'_ceMembers_@free.easypdfcombine.com', u'7.101.9.62366'),
#   {'avgBlockingTime': 370667,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.697394789579159}),
#  ((u'tabscope@xuldev.org', u'1.6.3'),
#   {'avgBlockingTime': 370363,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.02997933923870799}),
#  ((u'{a95d8332-e4b4-6e7f-98ac-20b733364387}', u'1.0.5'),
#   {'avgBlockingTime': 366307L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 18.134631698717044}),
#  ((u'shopearn@prodege.com', u'219'),
#   {'avgBlockingTime': 365411L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 285.54161086855873}),
#  ((u'nextpage@yuanle.song', u'1.4.1'),
#   {'avgBlockingTime': 364870,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.38800591547539737}),
#  ((u'googledictionary@toptip.ca', u'7.2.1-signed'),
#   {'avgBlockingTime': 364509,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 28.57409490316655}),
#  ((u'alldownloader@link64', u'1.00.17.1-signed.1-signed'),
#   {'avgBlockingTime': 363831,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 23.553370142764276}),
#  ((u'{1A2D0EC4-75F5-4c91-89C4-3656F6E44B68}', u'0.6.3.1-signed.1-signed'),
#   {'avgBlockingTime': 361430,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.7925052726884667}),
#  ((u'antmark@ant.com', u'1.1.14'),
#   {'avgBlockingTime': 359914,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.277137595979015}),
#  ((u'fox@replace.fx', u'0.17.1.1-signed.1-let-fixed'),
#   {'avgBlockingTime': 359824,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0009449766354526883}),
#  ((u'cpmanager@mozillaonline.com', u'1.5.14'),
#   {'avgBlockingTime': 359423,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.1142827664477077}),
#  ((u'{c45c406e-ab73-11d8-be73-000a95be3b12}', u'1.2.10'),
#   {'avgBlockingTime': 357386,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.44052742748967855}),
#  ((u'addon@compareraja.com', u'3.0'),
#   {'avgBlockingTime': 356674,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.354558161205156}),
#  ((u'{ea614400-e918-4741-9a97-7a972ff7c30b}', u'3.0.14'),
#   {'avgBlockingTime': 355506,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.940446650124069}),
#  ((u'{5546F97E-11A5-46b0-9082-32AD74AAA920}', u'0.76'),
#   {'avgBlockingTime': 354348,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.540090246442207}),
#  ((u'{023e9ca0-63f3-47b1-bcb2-9badf9d9ef28}', u'4.4.3.1-signed.1-signed'),
#   {'avgBlockingTime': 352623,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2409430562213744}),
#  ((u'sipgateffx@michael.rotmanov', u'0.7.5.1-signed.1-signed'),
#   {'avgBlockingTime': 352556,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 42.69417271631583}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.1a3'),
#   {'avgBlockingTime': 352050,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.1710233997051678}),
#  ((u'linkwidget@clav.mozdev.org', u'1.7.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 351703,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 21.576738530239272}),
#  ((u'{E4091D66-127C-11DB-903A-DE80D2EFDFE8}', u'1.7.0.4a'),
#   {'avgBlockingTime': 351486,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.543012141565487}),
#  ((u'IBM-cck@firefox-extensions.ibm.com', u'2.2.5'),
#   {'avgBlockingTime': 351339,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2068079912197309}),
#  ((u'cyscon-phishing-protection@patugo.com', u'1.17.0'),
#   {'avgBlockingTime': 350081,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9040917947607707}),
#  ((u'searchimage@searchimage.fr', u'0.1.2.1-signed.1-signed'),
#   {'avgBlockingTime': 349200,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.13934045517882024}),
#  ((u'tiletabs@DW-dev', u'14.3'),
#   {'avgBlockingTime': 347741,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.02547887442329604}),
#  ((u'{065ee92a-ad57-42a2-b6d5-466b6fd8e24d}', u'0.11.6.1-signed.1-signed'),
#   {'avgBlockingTime': 345470,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.011009286026950232}),
#  ((u'vocabhighlighter@name.domain', u'0.73.1-signed.1-signed'),
#   {'avgBlockingTime': 344165,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.003909319312815}),
#  ((u'_5zMembers_@www.couponxplorer.com', u'7.38.8.45876'),
#   {'avgBlockingTime': 342553,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.19797211323853173}),
#  ((u'eagleget_ffext@eagleget.com', u'4.0'),
#   {'avgBlockingTime': 342273,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.4256055363321796}),
#  ((u'quickdrag@mozilla.ktechcomputing.com', u'2.1.3.23.1-signed.1-signed'),
#   {'avgBlockingTime': 341493,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9244576947964428}),
#  ((u'scrapbookx@addons.mozilla.org', u'1.13.1'),
#   {'avgBlockingTime': 339298,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.301568403298644}),
#  ((u'LVD-SAE@iacsearchandmedia.com', u'2.1'),
#   {'avgBlockingTime': 339005,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 81.73450603395378}),
#  ((u'{6e764c17-863a-450f-bdd0-6772bd5aaa18}', u'1.0.3.1-signed.1-signed'),
#   {'avgBlockingTime': 338918,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.6749512065480185}),
#  ((u'{68836a21-fc7d-4ea1-a065-7efabd99d414}', u'3.05.1-signed.1-signed'),
#   {'avgBlockingTime': 334968,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5888335150597929}),
#  ((u'youtubemp3podcaster@jeremy.d.gregorio.com', u'3.9.0'),
#   {'avgBlockingTime': 333970,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.49065437218532}),
#  ((u'{2AD817C2-AC9D-4B7C-8E71-2D38FB87330A}', u'1.0.11'),
#   {'avgBlockingTime': 331296,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.475289748908455}),
#  ((u'ankpixiv@snca.net', u'2.1.3'),
#   {'avgBlockingTime': 330192,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.7441065215083094}),
#  ((u'@90B817C8-8A5C-413B-9DDD-B2C61ED6E79A', u'1.09'),
#   {'avgBlockingTime': 326441,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.658856532905954}),
#  ((u'test@example.com', u'v1.6.5'),
#   {'avgBlockingTime': 323293,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.8656125124517673}),
#  ((u'dimmer@tejohnso.github.com', u'1.3.1-signed.1-signed'),
#   {'avgBlockingTime': 322979,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.08447142354336766}),
#  ((u'readable@evernote.com', u'10.2.1.7.1-signed'),
#   {'avgBlockingTime': 320601,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.10527341143336813}),
#  ((u'LVD-SAE@iacsearchandmedia.com', u'8.5'),
#   {'avgBlockingTime': 319988L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.78753852688442}),
#  ((u'markdown-here@adam.pritchard', u'2.12.0'),
#   {'avgBlockingTime': 319689,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.364140275171966}),
#  ((u'toolbar_TeoShopTB@apn.ask.com', u'134.1'),
#   {'avgBlockingTime': 318434,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.228677556074099}),
#  ((u'{f4b962b4-ab75-41bf-8da7-a0435258a27c}',
#    u'0.5.5-1.1-signed.1-signed.1-signed'),
#   {'avgBlockingTime': 316609,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.3674901143756113}),
#  ((u'scrapbookx@addons.mozilla.org', u'1.12.38'),
#   {'avgBlockingTime': 314839,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.2065539478633525}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.19'),
#   {'avgBlockingTime': 313490L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.826714909370539}),
#  ((u'chromatabs@corilica.com', u'4.0b2'),
#   {'avgBlockingTime': 313419,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.920812169535838}),
#  ((u'support@lastpass.com', u'3.1.92'),
#   {'avgBlockingTime': 312988,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 65.73576799140709}),
#  ((u'{19503e42-ca3c-4c27-b1e2-9cdb2170ee34}', u'1.5.6.13'),
#   {'avgBlockingTime': 312703L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 51.659329756234904}),
#  ((u'snaplinks@snaplinks.mozdev.org', u'2.4.3'),
#   {'avgBlockingTime': 311306,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3521356374307141}),
#  ((u'scrollprogress@com.sppad', u'2.2.0.1-signed'),
#   {'avgBlockingTime': 309579,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.554800767597464}),
#  ((u'paulsaintuzb@gmail.com', u'8.2.1'),
#   {'avgBlockingTime': 309318L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 54.57344091253026}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.22'),
#   {'avgBlockingTime': 308405,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 66.59208339187767}),
#  ((u'ar1er-ewrgfdgomusix@jetpack', u'1.0.3'),
#   {'avgBlockingTime': 305870,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.008535744417682426}),
#  ((u'_dhMembers_@www.packagetracking.net', u'7.38.8.46567'),
#   {'avgBlockingTime': 305697,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.4532578965116714}),
#  ((u'inoreadersearch@wacha.zoltan', u'1.5.1-signed.1-signed'),
#   {'avgBlockingTime': 304589,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.3859810582588705}),
#  ((u'{0d4cca85-dc2d-45b2-bbaf-78d1b51629f0}', u'1.0.1'),
#   {'avgBlockingTime': 304021L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1183.0276366340315}),
#  ((u'_f7Members_@download.smsfrombrowser.com', u'7.38.8.45917'),
#   {'avgBlockingTime': 303949,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.9947499309201437}),
#  ((u'openinchrome@griffeltavla.wordpress.com', u'1.6.2'),
#   {'avgBlockingTime': 303356,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.629260092837879}),
#  ((u'netvideohunter@netvideohunter.com', u'1.20'),
#   {'avgBlockingTime': 303073,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0645545293592466}),
#  ((u'{35106bca-6c78-48c7-ac28-56df30b51d2a}', u'1.3.8.1-signed.1-signed'),
#   {'avgBlockingTime': 302394L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.898663329561737}),
#  ((u'safesearch@avira.com', u'1.4.1.371'),
#   {'avgBlockingTime': 301993,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.48233503346023004}),
#  ((u'googledictionary@toptip.ca', u'7.3'),
#   {'avgBlockingTime': 301528,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.9197080291970803}),
#  ((u'autoform@olifozzy', u'1.2.4.1-signed.1-signed'),
#   {'avgBlockingTime': 300287,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.5661698742929815}),
#  ((u'artur.dubovoy@gmail.com', u'13.2.4'),
#   {'avgBlockingTime': 300220L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 48.75655378617015}),
#  ((u'{13e8d46d-09b8-4fd6-b75a-25c04a0db747}', u'1.0.1'),
#   {'avgBlockingTime': 299514L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 670.8649427031321}),
#  ((u'flvto@hotger.com', u'1.7.5.2-signed'),
#   {'avgBlockingTime': 297630,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 79.34121593609264}),
#  ((u'lipikaar@lipikaar.databyte', u'0.4.2.1-signed'),
#   {'avgBlockingTime': 296808,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.16544497805556194}),
#  ((u'@jetpack-easy-turism2', u'7.1.0'),
#   {'avgBlockingTime': 296790,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.933669790915644}),
#  ((u'firefox@zemanta.com', u'1.1.2'),
#   {'avgBlockingTime': 293738,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.06003552101660149}),
#  ((u'vk@sergeykolosov.mp', u'0.3.9.4pre'),
#   {'avgBlockingTime': 293440,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.26560726447219}),
#  ((u'{abe58ed3-ce61-44b4-bd17-91dd88bde3a7}', u'2.0.5962.9232'),
#   {'avgBlockingTime': 288679,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 87.66320052308535}),
#  ((u'jid0-InKc7nis87yL1cIBwQAskGTCWmY@jetpack', u'1.0.3.1-signed.1-signed'),
#   {'avgBlockingTime': 288451,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0014984802912379695}),
#  ((u'ffext_basicvideoext@startpage24', u'1.97.37.1-signed.1-signed'),
#   {'avgBlockingTime': 287877,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.6974657916524754}),
#  ((u'wrc@avast.com', u'7.0.1474'),
#   {'avgBlockingTime': 287809,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq':
),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.0'),
#   {'avgBlockingTime': 268594L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.357844240131433}),
#  ((u'multilinksplus@hugsmile.eu', u'3.6.6'),
#   {'avgBlockingTime': 268330,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.15413512571387}),
#  ((u'phrasehighlighter@techtoast.co.uk', u'1.9.5.1-signed.1-signed'),
#   {'avgBlockingTime': 267656,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.15854219473287598}),
#  ((u'sbconforming@masahal.info', u'0.5.1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 267428,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.4425529884338817}),
#  ((u'{6236BA26-C117-4007-928C-DE0716C7FA78}', u'1.0.85'),
#   {'avgBlockingTime': 265054,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.819899398846765}),
#  ((u'afterthedeadline@afterthedeadline.com', u'1.51.1-signed.1-signed'),
#   {'avgBlockingTime': 264306,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.7113190693918328}),
#  ((u'cliqz@cliqz.com', u'2.8.5'),
#   {'avgBlockingTime': 263945,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.7728946149017133}),
#  ((u'support@words-chinese.com', u'2.4.1-signed.1-signed'),
#   {'avgBlockingTime': 263683,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.16579080679742308}),
#  ((u'passifox@hanhuy.com', u'1.1.13'),
#   {'avgBlockingTime': 261979,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.027664359595690507}),
#  ((u'_12Members_@free.myscrapnook.com', u'7.38.8.45231'),
#   {'avgBlockingTime': 261933,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.8174055996859924}),
#  ((u'{158d7cb3-7039-4a75-8e0b-3bd0a464edd2}', u'2.7.1-signed.1-signed'),
#   {'avgBlockingTime': 261814,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.011298627851240464}),
#  ((u'ipprotocols@jcp.convenant', u'0.2.3.1-signed.1-signed'),
#   {'avgBlockingTime': 261428,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.643532001896837}),
#  ((u'isreaditlater@ideashower.com', u'3.0.6.1-signed'),
#   {'avgBlockingTime': 261192,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.245099118512308}),
#  ((u'_doMembers_@free.convertanyfile.com', u'7.102.10.3672'),
#   {'avgBlockingTime': 258475,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.7140023800079334}),
#  ((u'{731E8172-334E-4887-B304-D3949A04773A}', u'16.08.11.01'),
#   {'avgBlockingTime': 258327,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.0618366742291725}),
#  ((u'jid0-G6461UajDjhNAwSukoedlkhD0XA@jetpack', u'4.1.3'),
#   {'avgBlockingTime': 258129,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0053576670634068735}),
#  ((u'web2pdfextension.15@web2pdf.adobedotcom', u'15'),
#   {'avgBlockingTime': 257128,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0279131546437821}),
#  ((u'{1823e248-6bf4-f6f1-7901-65a68e8b6c1e}', u'1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 256534,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.114265292256662}),
#  ((u'{d2fd6a7c-5fbe-49eb-9c0c-f88fe8f80339}', u'2.0.6015.29123'),
#   {'avgBlockingTime': 256324,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.0004497413987}),
#  ((u'jid1-3FQ9OGtE8VwULA@jetpack', u'0.3.0.1-signed'),
#   {'avgBlockingTime': 256246,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.018106056224334036}),
#  ((u'autocopy2@teo.pl', u'1.2.91'),
#   {'avgBlockingTime': 255029,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5842183787133528}),
#  ((u'nimbusscreencaptureff@everhelper.me', u'9.1.1'),
#   {'avgBlockingTime': 254958,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.030043216010723118}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'5.4.2'),
#   {'avgBlockingTime': 254410,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.839122112377172}),
#  ((u'_dbMembers_@free.getformsonline.com', u'7.70.9.48617'),
#   {'avgBlockingTime': 252910,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.18127800997029056}),
#  ((u'secureLogin@blueimp.net', u'1.1.8'),
#   {'avgBlockingTime': 252769,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.003442014955554982}),
#  ((u'support@videoadd.ru', u'2.8.1.1-signed.1-signed'),
#   {'avgBlockingTime': 238454,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 24.499423758387813}),
#  ((u'{4ED1F68A-5463-4931-9384-8FFF5ED91D92}', u'5.0.218.0'),
#   {'avgBlockingTime': 237699,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.30301190953883}),
#  ((u'{ddaa9b77-a9a9-4bf8-a7e1-3ed66177701d}', u'2.0.5840.33538'),
#   {'avgBlockingTime': 237555,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.356888321118806}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'5.6.1'),
#   {'avgBlockingTime': 236928,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.77925137577266}),
#  ((u'anaglyph3d@internauta1024a.pl', u'0.2.4.1-signed.1-signed'),
#   {'avgBlockingTime': 236383,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.046653577746243416}),
#  ((u'{066217d1-08c9-4d90-b615-cee305e7074f}', u'2.0.6020.254'),
#   {'avgBlockingTime': 235999,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.436747269162543}),
#  ((u's3google@translator', u'5.25'),
#   {'avgBlockingTime': 235410L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.49096276952914}),
#  ((u'safesearchplus2@avira.com', u'1.4.1.371'),
#   {'avgBlockingTime': 234937,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.025681249213281625}),
#  ((u'plugin@skiptco.org', u'1.2.1.1-signed.1-signed'),
#   {'avgBlockingTime': 234699,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.062823885832735}),
#  ((u'spdyindicator@chengsun.github.com', u'2.3'),
#   {'avgBlockingTime': 233793,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.963254145940015}),
#  ((u'jid1-dwtFBkQjb3SIQp@jetpack', u'0.3.4'),
#   {'avgBlockingTime': 232890,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.011870074908086052}),
#  ((u'commentblocker@xertoz.se', u'4.0.4.1-signed'),
#   {'avgBlockingTime': 232533,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.547640484730482}),
#  ((u'{49f3fc85-dcfe-4e42-9301-226ebe658509}', u'0.6.7.1-signed.1-signed'),
#   {'avgBlockingTime': 232100,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.01751150623275138}),
#  ((u'{d57c9ff1-6389-48fc-b770-f78bd89b6e8a}', u'1.46.1-signed.1-signed'),
#   {'avgBlockingTime': 231579,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.664450841776038}),
#  ((u'{9efe12fc-8e7b-41dc-917e-b9341daa31e0}', u'1.3.4.3.1-signed.1-signed'),
#   {'avgBlockingTime': 231198,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.557122658431756}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.18.2016090801'),
#   {'avgBlockingTime': 230777,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.24803125193774414}),
#  ((u'{3c836676-f0ac-4921-b55a-03cfbf37b751}', u'1.0.1'),
#   {'avgBlockingTime': 230432,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.76773851322337}),
#  ((u'{fe272bd1-5f76-4ea4-8501-a05d35d823fc}',
#    u'2.1.9.1-signed.1-let-fixed.1-signed'),
# ...
#   {'avgBlockingTime': 84592,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.4336382892424173}),
#  ((u'killspinners@byo.co.il', u'1.3.1'),
#   {'avgBlockingTime': 84504,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.004602671211378315}),
#  ((u'FasterFox_Lite@BigRedBrent', u'3.9.9Lite.1-signed.1-signed'),
#   {'avgBlockingTime': 84419,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.007001266504358686}),
#  ((u'_9eMembers_@free.findmefreebies.com', u'7.38.8.46369'),
#   {'avgBlockingTime': 84338,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.8562577591107915}),
#  ((u'dc77187f-1ad7-4b19-8787-a0a5cc10343f@e6264eef-2457-4fa2-bea4-bd6135e1199d.com',
#    u'0.93.12'),
#   {'avgBlockingTime': 84262,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4976658620359638}),
#  ((u'mp4downloader@jeff.net', u'1.3.3.1-signed.1-signed'),
#   {'avgBlockingTime': 84130,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5434444906615125}),
#  ((u'tileview@DW-dev', u'6.1'),
#   {'avgBlockingTime': 84118,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3254818798045973}),
#  ((u'{a182d6e5-aab8-0e32-ddd5-f043d20bd099}', u'1.1'),
#   {'avgBlockingTime': 84100,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3980044499108636}),
#  ((u'_flMembers_@free.myformsfinder.com', u'7.102.10.4784'),
#   {'avgBlockingTime': 84008,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.09232071189526728}),
#  ((u'{66E978CD-981F-47DF-AC42-E3CF417C1467}', u'0.5.2'),
#   {'avgBlockingTime': 83811,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0014404868125182907}),
#  ((u'{a3a5c777-f583-4fef-9380-ab4add1bc2a5}', u'2.4.2.1-signed'),
#   {'avgBlockingTime': 83221,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.002069710930373391}),
#  ((u'wx-assistant@mozillaonline.com', u'1.1.5'),
#   {'avgBlockingTime': 83139,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.0736758372877637}),
#  ((u'{DEDA1132-B316-11DD-8BC1-4E5D56D89593}', u'0.18'),
#   {'avgBlockingTime': 83019,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.8705429252511265}),
#  ((u'{8743b663-b854-4f75-bc82-8f7e751e759f}', u'1.7.5.1-signed.1-signed'),
#   {'avgBlockingTime': 82602,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 18.558623905497125}),
#  ((u'vkpatch@pochemuto.org', u'6.1.8'),
#   {'avgBlockingTime': 82469,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.7889793362554791}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.12'),
#   {'avgBlockingTime': 82260,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.1719790464352304}),
#  ((u'_foMembers_@free.flightsearchapp.com', u'7.38.8.46367'),
#   {'avgBlockingTime': 82223,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3221392431964863}),
#  ((u'autoreload@yz.com', u'1.20.1-signed.1-signed'),
#   {'avgBlockingTime': 82215,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0287038161216143}),
#  ((u'{e415cc51-3140-44b2-93a8-79cfb83c1f31}', u'1.0.0'),
#   {'avgBlockingTime': 82202,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.42189148013594285}),
#  ((u'_9tMembers_@download.internetspeedtracker.com', u'7.38.8.56171'),
#   {'avgBlockingTime': 81933,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 3.510267283677197}),
#  ((u'abs@avira.com', u'1.10.0.734'),
#   {'avgBlockingTime': 81903,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.616181624257198}),
#  ((u'rememberpass@teesoft.info', u'1.1.2.1-signed.1-signed'),
#   {'avgBlockingTime': 81692,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.7249069556745125}),
#  ((u'unlisted-particle@particlecore.github.io', u'1.4.0'),
#   {'avgBlockingTime': 81585,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.02060581575300305}),
#  ((u'easycopy@smokyink.com', u'2.7.0'),
#   {'avgBlockingTime': 81093,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.04035686323330456}),
#  ((u'@translatenow', u'0.3.1'),
#   {'avgBlockingTime': 81072,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.001221372802673992}),
#  ((u'support@gdata.de', u'0.2.22.1-signed.1-signed'),
#   {'avgBlockingTime': 80724,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.2142857142857142}),
#  ((u'{268ad77e-cff8-42d7-b479-da60a7b93305}', u'1.6.11'),
#   {'avgBlockingTime': 80630,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.05164696430620911}),
#  ((u'{f3bd3dd2-2888-44c5-91a2-2caeb33fb898}', u'48.1'),
#   {'avgBlockingTime': 80593,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.00013601580685030008}),
#  ((u'easyscreenshot@mozillaonline.com', u'1.2.7.2'),
#   {'avgBlockingTime': 80494,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.004574489849079956}),
#  ((u'jid0-1kqApO5BUHwjBQft5BEUXHXZjCA@jetpack', u'0.2.9'),
#   {'avgBlockingTime': 80150,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.005799599666523019}),
#  ((u'{7b8a500a-a464-4624-bd4f-73eaafe0f766}', u'3.0'),
#   {'avgBlockingTime': 80001,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.033896635257263066}),
#  ((u'{B100D0FF-0001-8CE4-2790-AACE49B8AE35}', u'3.7.1'),
#   {'avgBlockingTime': 79956,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.09654710023466309}),
#  ((u'fb2reader@clear.com.ua', u'0.28'),
#   {'avgBlockingTime': 79830,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.002360970017648251}),
#  ((u'abs@avira.com', u'1.6.0'),
#   {'avgBlockingTime': 79653,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3745101892201172}),
#  ((u'{8cc5e9ec-4d7b-45f3-869c-054d84aaa512}', u'2.0.5705.39030'),
#   {'avgBlockingTime': 79465,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.0083092148258799}),
#  ((u'{41ca0b9f-fccf-4Ea1-b7c9-e379c1498afc}', u'0.6.3.1-signed.1-signed'),
#   {'avgBlockingTime': 79381,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2869543383909035}),
#  ((u'jid1-kyxEAcWua7BEKq@jetpack', u'0.1.7'),
#   {'avgBlockingTime': 79297,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0013747241911857954}),
#  ((u'{068e178c-61a9-4a63-b74f-87404a6f5ea1}', u'2.0'),
#   {'avgBlockingTime': 78912,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.08744619617327537}),
#  ((u'trackerblock@privacychoice.org', u'2.2.1-signed.1-signed'),
#   {'avgBlockingTime': 78699,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5176882856154719}),
#  ((u'_ftMembers_@free.mytelevisionhq.com', u'7.38.8.59043'),
#   {'avgBlockingTime': 78608,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.7115251897860593}),
#  ((u'{74591c01-3a7f-469e-ad4e-5d8d708dc4c5}', u'1.2.2'),
#   {'avgBlockingTime': 78594,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.007967137769793428}),
#  ((u'_94Members_@www.motitags.com', u'7.102.10.4744'),
#   {'avgBlockingTime': 78246,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.196604441709409}),
#  ((u'ipdata@extension', u'1.0.1.4.1-signed.1-signed'),
#   {'avgBlockingTime': 78242,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.20140761544572625}),
#  ((u'_gcMembers_@www.weatherblink.com', u'7.38.8.56523'),
#   {'avgBlockingTime': 78216,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.249987393511188}),
#  ((u'info@convert2mp3.net', u'2.5.1-signed.1-signed'),
#   {'avgBlockingTime': 78128,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4886581246322059}),
#  ((u'wrc@avast.com', u'10.3.3.44'),
#   {'avgBlockingTime': 77896L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.979416744153674}),
#  ((u'stoptube@kashiif.com', u'0.2.1.1-signed.1-signed'),
#   {'avgBlockingTime': 77858,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.05857972072350605}),
#  ((u'windowpromo@dm73.net', u'1.6'),
#   {'avgBlockingTime': 77769,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.012056545196973807}),
#  ((u'nst@neiron.ru', u'7.3.0.2'),
#   {'avgBlockingTime': 77466,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.04803864442062281}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.17.2016083101'),
#   {'avgBlockingTime': 77245,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.0693015632613543}),
#  ((u'youtube-video-player@lejenome.me', u'0.2.38.1-signed.1-signed'),
#   {'avgBlockingTime': 77196,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.005649294910456061}),
#  ((u'jid0-BumCY9dUzYckeJaH3JEeimjBpxM@jetpack', u'0.16.1-signed.1-signed'),
#   {'avgBlockingTime': 77193,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.005042474089912216}),
#  ((u'_4zMembers_@www.videodownloadconverter.com', u'7.101.10.2695'),
#   {'avgBlockingTime': 77162,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 5.709849601996888}),
#  ((u'{8522e648-adce-469a-8c3a-18659a6ab6e3}', u'0.4.7.1-signed.1-signed'),
#   {'avgBlockingTime': 77137,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.005111080823224751}),
#  ((u'showmethepassword@alejandrobrizuela.com.ar', u'1.1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 74829,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3877654709887207}),
#  ((u'jid1-0GRQcsmyXNQRlg@jetpack', u'2.6.0'),
#   {'avgBlockingTime': 74770,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.0025485922744380796}),
#  ((u'info@lelivros.club', u'4.5'),
#   {'avgBlockingTime': 74626,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.08101379766241437}),
#  ((u'_brMembers_@free.yourtemplatefinder.com', u'7.38.8.45986'),
#   {'avgBlockingTime': 74517,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3308046516851638}),
#  ((u'lazarus@interclue.com', u'3.2'),
#   {'avgBlockingTime': 73930,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.018084212147902064}),
#  ((u'_d0Members_@free.gostudyhq.com', u'7.38.8.45922'),
#   {'avgBlockingTime': 73818,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.833479633192013}),
#  ((u'@doublestitch', u'0.0.2'),
#   {'avgBlockingTime': 73685,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.01211705070985722}),
#  ((u'{2bfc8624-5b8a-4060-b86a-e78ccbc38509}', u'5.5.2.1-signed.1-signed'),
#   {'avgBlockingTime': 73422,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.7026679215883471}),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.7.1.9'),
#   {'avgBlockingTime': 73286,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 31.836164766115893}),
#  ((u'jid0-c2sDaWXwVfmCLg6SAnPzpgA8pwU@jetpack', u'1.6.4'),
#   {'avgBlockingTime': 73125,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.436033974387185}),
#  ((u'{7c70a669-5a3f-4390-a507-670639880928}',
#    u'1.0.12051100.1-signed.1-signed'),
#   {'avgBlockingTime': 73109,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.813702791582487}),
#  ((u'{E71B541F-5E72-5555-A47C-E47863195841}', u'3.0.3'),
#   {'avgBlockingTime': 73082,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.12733110643777443}),
#  ((u'WSVCU@Wondershare.com', u'7.1.0'),
#   {'avgBlockingTime': 72815,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 4.843820200931974}),
#  ((u'snt@simplenewtab.com', u'1.3'),
#   {'avgBlockingTime': 72115,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.788108922312512}),
#  ((u'_4jMembers_@www.radiorage.com', u'7.102.10.4916'),
#   {'avgBlockingTime': 71821,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.5216378268568134}),
#  ((u'ffpwdman@bitdefender.com', u'1.1'),
#   {'avgBlockingTime': 71654,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.34383688600556}),
#  ((u'jid0-zxGf4jM5hHg1dJ5Gf1H7NfFfe76@jetpack', u'0.1.5'),
#   {'avgBlockingTime': 71483,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.01117294161827645}),
#  ((u'keeppy.com@keppy-ff-plugin', u'2.4.6.1-signed.1-signed'),
#   {'avgBlockingTime': 71267,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 1.578918210190024}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.17.2016083100a030417'),
#   {'avgBlockingTime': 71227,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.24053082364014206}),
#  ((u'exsoc@biz-taks.lv', u'14.6.26'),
#   {'avgBlockingTime': 71067,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 2.1336680263570758}),
#  ((u'_8lMembers_@free.filesharefanatic.com', u'7.38.8.46365'),
#   {'avgBlockingTime': 70864,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2171916218331878}),
#  ((u'@moar-private', u'0.0.1'),
#   {'avgBlockingTime': 70794,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.035902703673046044}),
#  ...]

# %% [markdown]
# The blocking CPOW data, ordered by decreasing occurrence frequency.

# %%
sorted(cpowHadBlocking, key = lambda (addon, summary): summary["occurrenceFreq"], reverse = True)
# Out:
# [((u'{0d4cca85-dc2d-45b2-bbaf-78d1b51629f0}', u'1.0.1'),
#   {'avgBlockingTime': 304021L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 173.0989937072048}),
#  ((u'{a0d7ccb3-214d-498b-b4aa-0e8fda9a7bf7}', u'20150708'),
#   {'avgBlockingTime': 62968,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 166.35398698077336}),
#  ((u'{50318622-2f25-46f9-adea-c7f9ceff0093}', u'2.0.5939.33141'),
#   {'avgBlockingTime': 121925,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 157.5100646340752}),
#  ((u'jid1-NIfFY2CA8fy1tg@jetpack', u'2.0'),
#   {'avgBlockingTime': 7300,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 102.47571059753801}),
#  ((u'{40AC5270-A9D0-11DE-B979-F0B655D89593}', u'4.2.20160628'),
#   {'avgBlockingTime': 286847,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 100.53233557028356}),
#  ((u'facefont@mc.com', u'7.0.2'),
#   {'avgBlockingTime': 153774,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 95.46033092914722}),
#  ((u'toolbar_BTR-SP@apn.ask.com', u'119.6'),
#   {'avgBlockingTime': 91352,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 94.37515907355561}),
#  ((u'{abe58ed3-ce61-44b4-bd17-91dd88bde3a7}', u'2.0.5962.9232'),
#   {'avgBlockingTime': 288679,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 87.66320052308535}),
#  ((u'{72CA2996-F580-47DF-98FF-0B853D09CEC8}', u'7.0.4.8'),
#   {'avgBlockingTime': 784114,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 87.57307184612483}),
#  ((u'thumbnailZoom@dadler.github.com', u'4.0'),
#   {'avgBlockingTime': 154214L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 84.44116632959188}),
#  ((u'_4zMembers_@www.videodownloadconverter.com', u'7.200.9.50819'),
#   {'avgBlockingTime': 55836,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 82.98930239566069}),
#  ((u'LVD-SAE@iacsearchandmedia.com', u'2.1'),
#   {'avgBlockingTime': 339005,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 81.73450603395378}),
#  ((u'flvto@hotger.com', u'1.7.5.2-signed'),
#   {'avgBlockingTime': 297630,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 79.34121593609264}),
#  ((u'{d84a846d-f7cb-4187-a408-b171020e8940}', u'1.4.0'),
#   {'avgBlockingTime': 152130L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 78.9165902584813}),
#  ((u'gvoice@elijahclark.com', u'5.2.1-signed.1-signed'),
#   {'avgBlockingTime': 806129,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 76.32099124075607}),
#  ((u'{fa1b1dca-f14d-44f8-b096-43de88243cf4}', u'1.0.1'),
#   {'avgBlockingTime': 245240,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 75.8539774060541}),
#  ((u'{152455DE-7B40-4bcf-B5B4-C68A1BE85A91}', u'2.7.1-signed.1-signed'),
#   {'avgBlockingTime': 247880,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 74.19814851290133}),
#  ((u'{71238372-3743-33ab-8a9f-93722af74c97}', u'1.0.5'),
#   {'avgBlockingTime': 140146,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 74.06858202038924}),
#  ((u'docview@mozilla.org', u'2.3.1-signed.1-signed'),
#   {'avgBlockingTime': 814524,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 73.56553822866242}),
#  ((u'{00D0643E-B367-4779-B45D-7046EBA37A89}', u'17.0.1.11430'),
#   {'avgBlockingTime': 242220,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 71.3854642641607}),
#  ((u'support@lastpass.com', u'3.2.40'),
#   {'avgBlockingTime': 554621L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 70.00146729526446}),
#  ((u'_fsMembers_@free.pdfconverterhq.com', u'7.101.9.61436'),
#   {'avgBlockingTime': 45557,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 68.3476713141501}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.22'),
#   {'avgBlockingTime': 308405,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 66.59208339187767}),
#  ((u'support@lastpass.com', u'3.1.92'),
#   {'avgBlockingTime': 312988,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 65.73576799140709}),
#  ((u'bughunter2@hostnameintitlebar', u'3.0.2.1-signed.1-signed'),
#   {'avgBlockingTime': 218397L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 59.09639333448818}),
#  ((u'firefox@ghostery.com', u'6.1.0'),
#   {'avgBlockingTime': 25675,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 58.26042127240337}),
#  ((u'{4b9bcce8-a70b-402a-a7e1-db96831ee26f}', u'4.7.0.35'),
#   {'avgBlockingTime': 6813,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 57.39001646851639}),
#  ((u'{9AA46F4F-4DC7-4c06-97AF-5035170634FE}', u'8.27'),
#   {'avgBlockingTime': 144508,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 57.333093395717114}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.16'),
#   {'avgBlockingTime': 119661,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 54.79753780801982}),
#  ((u'paulsaintuzb@gmail.com', u'8.2.1'),
#   {'avgBlockingTime': 309318L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 54.57344091253026}),
#  ((u'@firefoxinvertcolors', u'0.0.3'),
#   {'avgBlockingTime': 143326,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 54.41035232270131}),
#  ((u'alawar@Alawar', u'1.5.2'),
#   {'avgBlockingTime': 270973,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 53.2352499624681}),
#  ((u'_beMembers_@free.dailylocalguide.com', u'7.102.10.3762'),
#   {'avgBlockingTime': 67223,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 52.10927821607876}),
#  ((u'{19503e42-ca3c-4c27-b1e2-9cdb2170ee34}', u'1.5.6.13'),
#   {'avgBlockingTime': 312703L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 51.659329756234904}),
#  ((u'FGZ-SAE@iacsearchandmedia.com', u'8.5'),
#   {'avgBlockingTime': 243263,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 51.57715220184558}),
#  ((u'AddPageTitleToURLBar@ZXSpectrum', u'1.0.20.1-signed'),
#   {'avgBlockingTime': 104640,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 51.48314825506584}),
#  ((u'{113c6a96-cbc4-4248-bc8a-c05e9ec4b669}', u'1.2'),
#   {'avgBlockingTime': 58497,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 50.42218037141895}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.17'),
#   {'avgBlockingTime': 95669,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 49.81352548809581}),
#  ((u'setpoint-lt@addon-id.com', u'6.5'),
#   {'avgBlockingTime': 53974,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 49.705765127892526}),
#  ((u'artur.dubovoy@gmail.com', u'13.2.4'),
#   {'avgBlockingTime': 300220L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 48.75655378617015}),
#  ((u'{ef62e1ce-d2a4-4cdd-b7ec-92b120366b66}', u'2.7.8'),
#   {'avgBlockingTime': 94991,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 45.6988208003093}),
#  ((u'_8hMembers_@download.allin1convert.com', u'7.201.9.58796'),
#   {'avgBlockingTime': 25672,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 45.17195414556119}),
#  ((u'coba@mozilla.com.cn', u'1.0.33'),
#   {'avgBlockingTime': 165436L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 44.41679193926194}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.14rc1'),
#   {'avgBlockingTime': 124658L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 44.31793988021485}),
#  ((u'{3E5EE13F-9517-4DDF-BABF-83303B9AB98F}', u'1.26.1-signed.1-signed'),
#   {'avgBlockingTime': 396235,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.98580548705567}),
#  ((u'{7DD78D43-0962-4d9b-BC76-ABF13B3B2ED1}', u'3.5.0.1406'),
#   {'avgBlockingTime': 176891,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.84405279169782}),
#  ((u'antgroup@antdownloadmanager.com', u'0.1.7'),
#   {'avgBlockingTime': 165422,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.825205826472455}),
#  ((u'LVD-SAE@iacsearchandmedia.com', u'8.5'),
#   {'avgBlockingTime': 319988L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 43.78753852688442}),
#  ((u'sipgateffx@michael.rotmanov', u'0.7.5.1-signed.1-signed'),
#   {'avgBlockingTime': 352556,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 42.69417271631583}),
#  ((u'{3B4DE07A-DE43-4DBC-873F-05835FF67DCE}', u'4.18'),
#   {'avgBlockingTime': 57778,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 41.46912963981634}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.14'),
#   {'avgBlockingTime': 145989L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 40.84642621160736}),
#  ((u'_fsMembers_@free.pdfconverterhq.com', u'7.38.8.61250'),
#   {'avgBlockingTime': 36271,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 40.51317403332229}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.12rc1'),
#   {'avgBlockingTime': 113478,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 40.0187793845079}),
#  ((u'speedanalysis02@SpeedAnalysis.com', u'3.0.0.0'),
#   {'avgBlockingTime': 107633,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 39.36978683966636}),
#  ((u'{FCC777BA-8BCF-434b-A121-397D6270680F}', u'1.5.7.19.1-signed.1-signed'),
#   {'avgBlockingTime': 211690,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 38.99249018811983}),
#  ((u'priv3plus@icsi.berkeley.edu', u'0.18.2'),
#   {'avgBlockingTime': 104896,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 38.73360002856234}),
#  ((u'{b5ff4533-981b-4303-87ae-ff7b33382325}', u'2.0.5945.15307'),
#   {'avgBlockingTime': 115132,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 38.05788823052986}),
#  ((u'ISVCU@iSkysoft.com', u'5.1.0'),
#   {'avgBlockingTime': 62918,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 37.65886723587304}),
#  ((u'{7EE8902C-75BE-4286-A6CE-0C483607A322}', u'2.1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 5228,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 37.12845417699009}),
#  ((u'{458482f0-90fb-4257-855f-0ba2790584f9}', u'7.9'),
#   {'avgBlockingTime': 624552,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.74922282251876}),
#  ((u'{f36c6cd1-da73-491d-b290-8fc9115bfa55}',
#    u'3.0.9.1-signed.1-let-fixed.1-signed'),
#   {'avgBlockingTime': 712082L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.34194986620687}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.10'),
#   {'avgBlockingTime': 87786,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.34066139199609}),
#  ((u'{4ED1F68A-5463-4931-9384-8FFF5ED91D92}', u'5.0.218.0'),
#   {'avgBlockingTime': 237699,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.30301190953883}),
#  ((u'vk@sergeykolosov.mp', u'0.3.9.4pre'),
#   {'avgBlockingTime': 293440,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 36.26560726447219}),
#  ((u'lazarus@interclue.com', u'2.3.1-signed.1-signed'),
#   {'avgBlockingTime': 148473L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 35.86752619657458}),
#  ((u'{c0bcf963-624b-47fe-aa78-8cc02434cf32}', u'0.5.7Build201606242330'),
#   {'avgBlockingTime': 164365,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 35.23225899334614}),
#  ((u'xpirftoolbar@roboform.com', u'3.9.1'),
#   {'avgBlockingTime': 463877,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 35.222281735404394}),
#  ((u'{1B12EF76-2B5E-4DA1-B587-4762D49BFE03}', u'1.3.4'),
#   {'avgBlockingTime': 163460,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.89254108723135}),
#  ((u'{322e833a-a7d4-4277-97c6-334fa1622d6a}', u'3.8'),
#   {'avgBlockingTime': 285106,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.75862068965517}),
#  ((u'_4zMembers_@www.videodownloadconverter.com', u'7.100.9.59101'),
#   {'avgBlockingTime': 102404,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.566145092460886}),
#  ((u'{8AA36F4F-6DC7-4c06-77AF-5035170634FE}', u'2016.9.8'),
#   {'avgBlockingTime': 244951,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.0968754825758}),
#  ((u'Mr_Xyzzy@Orion.Pardus.at', u'2.7.0'),
#   {'avgBlockingTime': 95992,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.058583968248044}),
#  ((u'{d2fd6a7c-5fbe-49eb-9c0c-f88fe8f80339}', u'2.0.6015.29123'),
#   {'avgBlockingTime': 256324,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 34.0004497413987}),
#  ((u'_64Members_@www.televisionfanatic.com', u'7.102.10.14812'),
#   {'avgBlockingTime': 145040,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 33.92123701377144}),
#  ((u'thumbnailZoom@dadler.github.com', u'4.0beta1'),
#   {'avgBlockingTime': 107218,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 33.277121071529436}),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.7.1.9'),
#   {'avgBlockingTime': 73286,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 31.836164766115893}),
#  ((u'gemiusheatmap@gemius.com', u'2.16.6'),
#   {'avgBlockingTime': 92505,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 31.555344159815178}),
#  ((u'pentadactyl@dactyl.googlecode.com', u'1.2pre'),
#   {'avgBlockingTime': 55408,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 31.076955468996736}),
#  ((u'{60B7679C-BED9-11E5-998D-8526BB8E7F8B}', u'5.0'),
#   {'avgBlockingTime': 126574,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 30.872610047130458}),
#  ((u'hovertranslate@muhammadsafwat.com', u'1.0.9.1-signed.1-signed'),
#   {'avgBlockingTime': 146826,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 30.217630749363817}),
#  ((u'{bd54afa8-b14a-4d7a-aecf-37e34e882796}', u'1.4.9.2.1-signed.1-signed'),
#   {'avgBlockingTime': 119982,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 30.075983943288445}),
#  ((u's3google@translator', u'5.25'),
#   {'avgBlockingTime': 235410L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.49096276952914}),
#  ((u'_64Members_@www.televisionfanatic.com', u'7.102.10.14823'),
#   {'avgBlockingTime': 18204,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.432013769363166}),
#  ((u'scanner@sidex.ru', u'2.82'),
#   {'avgBlockingTime': 161629,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.4137738867816}),
#  ((u'{62b958b4-9962-4fc2-9983-01a9a42d6f2d}', u'0.4.2.1-signed.1-signed'),
#   {'avgBlockingTime': 610435,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.30005425935974}),
#  ((u'{efda3854-2bd9-45a1-9766-49d7ff18931d}', u'0.8.17.2'),
#   {'avgBlockingTime': 135194,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 29.099355928624224}),
#  ((u'{6E727987-C8EA-44DA-8749-310C0FBE3C3E}', u'1.0.0.62'),
#   {'avgBlockingTime': 115259,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 28.932767624020887}),
#  ((u'_dbMembers_@free.getformsonline.com', u'7.100.9.45091'),
#   {'avgBlockingTime': 58835,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 28.78373093468909}),
#  ((u'googledictionary@toptip.ca', u'7.2.1-signed'),
#   {'avgBlockingTime': 364509,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 28.57409490316655}),
#  ((u'{f759ca51-3a91-4dd1-ae78-9db5eee9ebf0}', u'8.1.0'),
#   {'avgBlockingTime': 118734,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 27.755807384267722}),
#  ((u'{4622aef0-e33e-4e1f-9b62-ca3f18b46b25}', u'1.0.1'),
#   {'avgBlockingTime': 208627,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 27.15935334872979}),
#  ((u'support@lastpass.com', u'3.3.1'),
#   {'avgBlockingTime': 269498L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 26.891899835276373}),
#  ((u'WHIZMUZTK-PNP@iacsearchandmedia.com', u'24.8'),
#   {'avgBlockingTime': 280528,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 26.671683330474572}),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.6.0.66'),
#   {'avgBlockingTime': 88661,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 26.105221044208843}),
#  ((u'_ceMembers_@free.easypdfcombine.com', u'7.101.9.62333'),
#   {'avgBlockingTime': 167952,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 25.464002837214803}),
#  ((u'coba@mozilla.com.cn', u'1.0.32'),
#   {'avgBlockingTime': 132884L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 25.42201286681289}),
#  ((u'support@videoadd.ru', u'2.8.1.1-signed.1-signed'),
#   {'avgBlockingTime': 238454,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 24.499423758387813}),
#  ((u'tuxi@did120.ru', u'1.5.1'),
#   {'avgBlockingTime': 90483,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq':

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.771454991642067}),
#  ((u'{5546F97E-11A5-46b0-9082-32AD74AAA920}', u'0.76.1-signed.1-signed'),
#   {'avgBlockingTime': 204194,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.746508316391985}),
#  ((u'gridtube@gridtube.txt', u'4.0.3.1-signed'),
#   {'avgBlockingTime': 114373,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.68339914227957}),
#  ((u'_ftMembers_@free.mytelevisionhq.com', u'7.102.10.4817'),
#   {'avgBlockingTime': 50660,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.618831369803974}),
#  ((u'_64Members_@www.televisionfanatic.com', u'7.101.9.62585'),
#   {'avgBlockingTime': 61017,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.507208066639308}),
#  ((u'support@thedragonportal.eu', u'3.186'),
#   {'avgBlockingTime': 40226,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.49404478323011}),
#  ((u'2conv@hotger.com', u'1.9.2.3-signed'),
#   {'avgBlockingTime': 186970,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.42767115439702}),
#  ((u'{56a863a2-45ea-44da-84b3-b02c7dea77ee}', u'2.0.5766.24825'),
#   {'avgBlockingTime': 545485,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.416470790687125}),
#  ((u'scrapbookx@addons.mozilla.org', u'1.13.0'),
#   {'avgBlockingTime': 190510,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.07124152389436}),
#  ((u'_paMembers_@www.filmfanatic.com', u'7.102.10.4163'),
#   {'avgBlockingTime': 28911,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.058668089285984}),
#  ((u'info@vkstiker.ru', u'1.4.7'),
#   {'avgBlockingTime': 56559,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.019360648356596}),
#  ((u'{83b51b97-65e1-47a5-b5a8-97961a288a24}', u'2.0.5787.9774'),
#   {'avgBlockingTime': 534536,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 17.012339196639537}),
#  ((u'{21e48e29-f574-4619-b65d-0f00eea92e5b}', u'1.87'),
#   {'avgBlockingTime': 64664,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.87557321919902}),
#  ((u'{9AA46F4F-4DC7-4c06-97AF-5035170634FE}', u'10.25'),
#   {'avgBlockingTime': 146464,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.865321667162622}),
#  ((u'{0A558D49-3BB2-42e2-A53B-257CC7AE7C08}', u'2.4'),
#   {'avgBlockingTime': 969547,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.861228674664094}),
#  ((u'YoutubeDownloader@PeterOlayev.com', u'2.4.0.1-signed'),
#   {'avgBlockingTime': 165916,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.622747164839303}),
#  ((u'itsalltext@docwhat.gerf.org', u'1.9.2'),
#   {'avgBlockingTime': 191868L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.328561023471508}),
#  ((u'{73a6fe31-595d-460b-a920-fcc0f8843232}', u'2.9.0.11'),
#   {'avgBlockingTime': 108541,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.26845172125407}),
#  ((u'{600452e8-6851-46db-80fd-fa571b2deaa7}', u'0.12.2'),
#   {'avgBlockingTime': 138865,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 16.045659580031085}),
#  ((u'isreaditlater@ideashower.com', u'3.0.6'),
#   {'avgBlockingTime': 110341,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.96759159675916}),
#  ((u'chromatabs@corilica.com', u'4.0b2'),
#   {'avgBlockingTime': 313419,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.920812169535838}),
#  ((u'googleviewer@brandon.siegel', u'1.1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 1148753,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.824071175695158}),
#  ((u'_e5Members_@www.productivityboss.com', u'7.102.10.4871'),
#   {'avgBlockingTime': 17767,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.728594366104879}),
#  ((u'{d10d0bf8-f5b5-c8b4-a8b2-2b9879e08c5d}', u'2.6.10'),
#   {'avgBlockingTime': 7746,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.640816077116385}),
#  ((u'passff@invicem.pro', u'0.1.31'),
#   {'avgBlockingTime': 123732,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.55709420833648}),
#  ((u'_fsMembers_@free.pdfconverterhq.com', u'7.102.10.4849'),
#   {'avgBlockingTime': 9040,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.2385655641929}),
#  ((u'ehtip@robertkatic', u'2.4.4.1-signed.1-let-fixed.1-signed'),
#   {'avgBlockingTime': 141708,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 15.01250033603054}),
#  ((u'canitbecheaper@trafficbroker.co.uk', u'3.9.71'),
#   {'avgBlockingTime': 193195,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.937014049949997}),
#  ((u'{1e3cded4-09a1-4be5-8b7a-b07d46bfaee0}', u'2.0.5826.21095'),
#   {'avgBlockingTime': 274352,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.885796797059596}),
#  ((u'{3c836676-f0ac-4921-b55a-03cfbf37b751}', u'1.0.1'),
#   {'avgBlockingTime': 230432,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.76773851322337}),
#  ((u'_dbMembers_@free.getformsonline.com', u'7.101.9.62422'),
#   {'avgBlockingTime': 30052,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.752988946537334}),
#  ((u'_g3Members_@free.easyphotoedit.com', u'7.102.10.4108'),
#   {'avgBlockingTime': 225084,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.72191712431353}),
#  ((u'linkalert.conlan@addons.mozilla.com', u'1.0.3'),
#   {'avgBlockingTime': 3586,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.70528524057657}),
#  ((u'{54affe52-8223-453b-be1e-2fe2e250045c}', u'8.0.0.49'),
#   {'avgBlockingTime': 132253,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.592313625845092}),
#  ((u'dash-out@gleuch.com', u'1.0.0'),
#   {'avgBlockingTime': 101177,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.484178638203204}),
#  ((u'wrc@avast.com', u'10.1.1607'),
#   {'avgBlockingTime': 157028,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.175654853620955}),
#  ((u'_e5Members_@www.productivityboss.com', u'7.38.8.46590'),
#   {'avgBlockingTime': 31518,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.057127022181541}),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.7.0.62'),
#   {'avgBlockingTime': 124987,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 14.045825652526931}),
#  ((u'cloud-to-butt-mozilla@github.com', u'1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 469728,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.986392296271669}),
#  ((u'wrc@avast.com', u'10.3.3.44'),
#   {'avgBlockingTime': 77896L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.979416744153674}),
#  ((u'_fsMembers_@free.pdfconverterhq.com', u'7.70.9.23820'),
#   {'avgBlockingTime': 13056,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.954209519871828}),
#  ((u'{F003DA68-8256-4b37-A6C4-350FA04494DF}', u'6.5'),
#   {'avgBlockingTime': 203471,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.837184137493209}),
#  ((u'vk@sergeykolosov.mp', u'0.3.9.5'),
#   {'avgBlockingTime': 485153L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.765299905919747}),
#  ((u'support@shoptimate.com', u'0.6.5.1-signed.1-signed'),
#   {'avgBlockingTime': 1517,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.65266420539294}),
#  ((u'{a3e4ea14-6491-41b6-9b30-b435214fd063}', u'2.0.5743.28298'),
#   {'avgBlockingTime': 175535,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.59603221549802}),
#  ((u'{E4091D66-127C-11DB-903A-DE80D2EFDFE8}', u'1.7.0.4a'),
#   {'avgBlockingTime': 351486,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.543012141565487}),
#  ((u'_agMembers_@free.premierdownloadmanager.com', u'7.39.8.50995'),
#   {'avgBlockingTime': 44876,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.304039583487187}),
#  ((u'{575cbcb9-3b7e-493a-b001-886b3ae793b5}', u'3.2.3.1-signed.1-signed'),
#   {'avgBlockingTime': 96969,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.291109473717215}),
#  ((u'yarip@mozdev.org', u'0.3.5.1-signed'),
#   {'avgBlockingTime': 275925,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.166997980809867}),
#  ((u'fastestsearch@mingyi.org', u'3.39.1'),
#   {'avgBlockingTime': 158638,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.15997408989002}),
#  ((u'{84b24861-62f6-364b-eba5-2e5e2061d7e6}', u'0.9.4.1-signed.1-signed'),
#   {'avgBlockingTime': 208054,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 13.13483316308327}),
#  ((u'minoru-kun@inbox.ru', u'1.36.1-signed.1-signed'),
#   {'avgBlockingTime': 114269,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.92747592039467}),
#  ((u'_ceMembers_@free.easypdfcombine.com', u'7.101.9.62366'),
#   {'avgBlockingTime': 370667,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.697394789579159}),
#  ((u'{A7C3D37C-DB07-4EDD-9693-A418CB36942E}', u'2.0.58'),
#   {'avgBlockingTime': 222606,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.667959163089888}),
#  ((u'abs@avira.com', u'1.10.0.734'),
#   {'avgBlockingTime': 81903,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.616181624257198}),
#  ((u'adbeaver@adbeaver.org', u'0.7.2.9'),
#   {'avgBlockingTime': 113630,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.564467697267224}),
#  ((u'autopagerfixed@mozilla.org', u'0.8.0.10.1-signed.1-signed'),
#   {'avgBlockingTime': 126221,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.512680903522403}),
#  ((u'anttoolbar@ant.com', u'2.4.7.43'),
#   {'avgBlockingTime': 248921L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.389577050975484}),
#  ((u'_dmMembers_@free.gounzip.com', u'7.102.10.4277'),
#   {'avgBlockingTime': 41403,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.375934131597122}),
#  ((u'{60B7679C-BED9-11E5-998D-8526BB8E7F8B}', u'4.8'),
#   {'avgBlockingTime': 91411,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.339371823276425}),
#  ((u'{4B797F68-9C25-4926-8959-728E54D7B699}', u'4.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 5277,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.305060346536202}),
#  ((u'@swordsandpotions2helper', u'1.0.0'),
#   {'avgBlockingTime': 419796,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.254995242626071}),
#  ((u's3fox@security', u'3.03'),
#   {'avgBlockingTime': 138290,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 12.12878955521133}),
#  ((u'{bee6eb20-01e0-ebd1-da83-080329fb9a3a}', u'1.86'),
#   {'avgBlockingTime': 201075L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.986766133452495}),
#  ((u'rpcontinued@amo.requestpolicy.org', u'1.0.beta12.2'),
#   {'avgBlockingTime': 16114,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.97445449707291}),
#  ((u'spdyindicator@chengsun.github.com', u'2.3'),
#   {'avgBlockingTime': 233793,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.963254145940015}),
#  ((u'_1cMembers_@www.bringmesports.com', u'7.102.10.3646'),
#   {'avgBlockingTime': 75702,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.954728813836129}),
#  ((u'wrc@avast.com', u'10.3.3.39'),
#   {'avgBlockingTime': 99841,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.924266334497368}),
#  ((u'{35106bca-6c78-48c7-ac28-56df30b51d2a}', u'1.3.8.1-signed.1-signed'),
#   {'avgBlockingTime': 302394L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.898663329561737}),
#  ((u'YoutubeDownloader@PeterOlayev.com', u'2.4.1'),
#   {'avgBlockingTime': 245076L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.897492949503913}),
#  ((u'{9A752782-D706-479b-98F8-3F66BF921692}', u'9.11.1-signed.1-signed'),
#   {'avgBlockingTime': 109081,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.873801226673464}),
#  ((u'_d0Members_@free.gostudyhq.com', u'7.38.8.45922'),
#   {'avgBlockingTime': 73818,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.833479633192013}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.19'),
#   {'avgBlockingTime': 313490L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.826714909370539}),
#  ((u'YoutubeDownloader@PeterOlayev.com', u'2.4.0.4'),
#   {'avgBlockingTime': 156226,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.822930564030347}),
#  ((u'webapps-team@lists.launchpad.net', u'3.0.2'),
#   {'avgBlockingTime': 58826,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.778354867145717}),
#  ((u'abs@avira.com', u'1.11.0.828.0'),
#   {'avgBlockingTime': 111544L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.54404873663628}),
#  ((u'_4zMembers_@www.videodownloadconverter.com', u'7.101.9.62598'),
#   {'avgBlockingTime': 18988,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.427025226875363}),
#  ((u'{6E727987-C8EA-44DA-8749-310C0FBE3C3E}', u'2.0.0.4'),
#   {'avgBlockingTime': 278803,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.42553646261764}),
#  ((u'helper@savefrom.net', u'2.37'),
#   {'avgBlockingTime': 204079,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.415327407482872}),
#  ((u'ffpwdman@bitdefender.com', u'1.1'),
#   {'avgBlockingTime': 71654,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.34383688600556}),
#  ((u'_fpMembers_@free.passwordlogic.com', u'7.102.10.4853'),
#   {'avgBlockingTime': 10864,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.17078410311493}),
#  ((u'multilinksplus@hugsmile.eu', u'3.6.6'),
#   {'avgBlockingTime': 268330,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.15413512571387}),
#  ((u'firefox@ghostery.com', u'6.3.2'),
#   {'avgBlockingTime': 20382,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.130463606306837}),
#  ((u'vocabhighlighter@name.domain', u'0.73.1-signed.1-signed'),
#   {'avgBlockingTime': 344165,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 11.003909319312815}),
#  ((u'{09D2D1C1-C4A3-4912-A96A-1ADDCCDA431F}', u'1.3.6'),
#   {'avgBlockingTime': 35949,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.997496711782425}),
#  ((u'cnnRssReader@readers.com', u'0.2.1-signed.1-signed'),
#   {'avgBlockingTime': 129316,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.971191995859927}),
#  ((u'@jetpack-easy-turism2', u'7.1.0'),
#   {'avgBlockingTime': 296790,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.933669790915644}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'5.4.2'),
#   {'avgBlockingTime': 254410,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.839122112377172}),
#  ((u'ff_bx_integration@1c-bitrix.ru', u'0.7'),
#   {'avgBlockingTime': 160736,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.826811947912894}),
#  ((u'{F74D5734-46F5-4B16-96F0-1E7FBF41B750}', u'4.70'),
#   {'avgBlockingTime': 92572,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.681598992264846}),
#  ((u'tinyurl.addon@fast-chat.co.uk', u'2.6.1.1-signed.1-signed'),
#   {'avgBlockingTime': 180996,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.674118769854257}),
#  ((u's3google@translator', u'5.21'),
#   {'avgBlockingTime': 148369,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.61031815259614}),
#  ((u'artur.dubovoy@gmail.com', u'13.2.3'),
#   {'avgBlockingTime': 201931,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.493544547202637}),
#  ((u'PageTitle@Merci.chao', u'5.2.4.1-signed'),
#   {'avgBlockingTime': 153671,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.405165339293594}),
#  ((u'flvmoviesdownloader@rzll', u'1.43.1-signed.1-signed'),
#   {'avgBlockingTime': 429301,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.391081489008771}),
#  ((u'MPS@MyPoints.com', u'121'),
#   {'avgBlockingTime': 396577,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.326993718196418}),
#  ((u'antmark@ant.com', u'1.1.14'),
#   {'avgBlockingTime': 359914,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.277137595979015}),
#  ((u'_h2Members_@free.calendarspark.com', u'7.38.9.3425'),
#   {'avgBlockingTime': 62840,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 10.22392135445112}),
#  ((u'{10f44e53-6a51-4507-9eee-af2b686cc879}', u'2.0.5954.35014'),
#   {'avgBlockingTime': 177933,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 9.991409502411948}),
#  ((u'_2vMembers_@www.dailybibleguide.com', u'7.38.8.52880'),
#   {'avgBlockingTime': 143035,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 9

#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.505926924782367}),
#  ((u'{CE6E6E3B-84DD-4cac-9F63-8D2AE4F30A4B}', u'4.0'),
#   {'avgBlockingTime': 276192,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.45651450046992}),
#  ((u'{9AF66764-4926-11E6-9599-A9A0E7BF5E87}', u'1.0'),
#   {'avgBlockingTime': 181688,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.407854706370424}),
#  ((u'yandexnext@everhelper.me', u'4.1.0'),
#   {'avgBlockingTime': 179810,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.315465341564366}),
#  ((u'info@gutscheinwahn.de', u'1.3.1-signed.1-signed'),
#   {'avgBlockingTime': 226714,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.053691275167786}),
#  ((u'abs@avira.com', u'1.12.0.9060'),
#   {'avgBlockingTime': 95142,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 8.011518162685311}),
#  ((u'Refunder@Refunder.pl', u'2.1.0.4'),
#   {'avgBlockingTime': 174353,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.992554424969714}),
#  ((u'{ea614400-e918-4741-9a97-7a972ff7c30b}', u'3.0.14'),
#   {'avgBlockingTime': 355506,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.940446650124069}),
#  ((u'flashPause@timnguyen001.org', u'0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 47592,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.922080407202587}),
#  ((u'firefox@ghostery.com', u'5.4.11'),
#   {'avgBlockingTime': 20090,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.912087912087912}),
#  ((u'_ceMembers_@free.easypdfcombine.com', u'7.38.8.46224'),
#   {'avgBlockingTime': 229736L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.747289316720812}),
#  ((u'{cabff3be-2f21-41c8-b7f5-a181dc8e249a}', u'2.0.5752.21281'),
#   {'avgBlockingTime': 248856,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.729302645139128}),
#  ((u'_8hMembers_@download.allin1convert.com', u'7.102.10.3584'),
#   {'avgBlockingTime': 63968,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.630447356692834}),
#  ((u'AllMyTube@Wondershare.com', u'4.9.0'),
#   {'avgBlockingTime': 48397,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.518769917718442}),
#  ((u'artur.dubovoy@gmail.com', u'10.1.0'),
#   {'avgBlockingTime': 100402,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.512520868113523}),
#  ((u'gte@melalawi.com', u'1.1.1021'),
#   {'avgBlockingTime': 213943,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.498555583559723}),
#  ((u'firefox@ghostery.com', u'5.4.9'),
#   {'avgBlockingTime': 13780,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.426680009237165}),
#  ((u'firefox@ghostery.com', u'6.3.0'),
#   {'avgBlockingTime': 2662,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.414428646656135}),
#  ((u'{C1A2A613-35F1-4FCF-B27F-2840527B6556}', u'2016.6.0.80'),
#   {'avgBlockingTime': 61023,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.32390970191989}),
#  ((u'_9tMembers_@free.internetspeedtracker.com', u'7.102.10.4339'),
#   {'avgBlockingTime': 49613,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.197863311442194}),
#  ((u'avg@toolbar', u'4.3.1.831'),
#   {'avgBlockingTime': 123976,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.165288159582468}),
#  ((u'bdwteffv20@bitdefender.com', u'3.0'),
#   {'avgBlockingTime': 217655,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.033964425038475}),
#  ((u'{bee6eb20-01e0-ebd1-da83-080329fb9a3a}', u'1.81'),
#   {'avgBlockingTime': 89882,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 7.023628874918708}),
#  ((u'{7e64a8d0-6956-44fb-879d-18ac83985ce2}', u'2.0.5775.9781'),
#   {'avgBlockingTime': 144641,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.898830370713012}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'6.0.0a6'),
#   {'avgBlockingTime': 210834,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.8949191934407885}),
#  ((u'_dbMembers_@free.getformsonline.com', u'7.102.10.4251'),
#   {'avgBlockingTime': 67205,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.861483171269451}),
#  ((u'_7jMembers_@download.gardeningenthusiast.com', u'7.102.10.4260'),
#   {'avgBlockingTime': 36930,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.821370225739255}),
#  ((u'{7443739c-bff6-4af0-aea5-7ed29006966c}', u'2.0.8.1-signed.1-signed'),
#   {'avgBlockingTime': 107686,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.800158261941532}),
#  ((u'{d10d0bf8-f5b5-c8b4-a8b2-2b9879e08c5d}', u'2.6.11'),
#   {'avgBlockingTime': 136963,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.567890314020345}),
#  ((u'autopager@mozilla.org', u'0.8.0.10.1-signed.1-signed'),
#   {'avgBlockingTime': 240436,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.531513287509856}),
#  ((u'snwteff19@sourcenext.com', u'19.0.4'),
#   {'avgBlockingTime': 131499,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.482969553732796}),
#  ((u'{2AD817C2-AC9D-4B7C-8E71-2D38FB87330A}', u'1.0.11'),
#   {'avgBlockingTime': 331296,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.475289748908455}),
#  ((u'{bee6eb20-01e0-ebd1-da83-080329fb9a3a}', u'1.83'),
#   {'avgBlockingTime': 100132,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.472089668183331}),
#  ((u'jid0-3GUEt1r69sQNSrca5p8kx9Ezc3U@jetpack', u'0.4.1.1-signed.1-signed'),
#   {'avgBlockingTime': 161003,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.468575772934617}),
#  ((u'_dbMembers_@free.getformsonline.com', u'7.101.9.60894'),
#   {'avgBlockingTime': 100451,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.394316163410302}),
#  ((u'{258735dc-6743-4805-95fc-f95941fffdad}', u'1.3.6.1-signed.1-signed'),
#   {'avgBlockingTime': 282183,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.33797298403317}),
#  ((u'{6E727987-C8EA-44DA-8749-310C0FBE3C3E}', u'1.0.0.69'),
#   {'avgBlockingTime': 223184,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.316594833082553}),
#  ((u'wrc@avast.com', u'10.3.3.13'),
#   {'avgBlockingTime': 195762,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.263993841791338}),
#  ((u'toolbar_AVIRA-V7@apn.ask.com', u'127.25'),
#   {'avgBlockingTime': 124572,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.252170892671067}),
#  ((u'wrc@avast.com', u'12.0.88'),
#   {'avgBlockingTime': 118116L,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 6.146225986763319}),
#  ((u'{06A1F7DC-C10E-11E4-B8DA-82C01D5D46B0}', u'0.9.20.05.01'),
#   {'avgBlockingTime': 227462,
#    'hadCPOWBlocking': True,
# ...
#   {'avgBlockingTime': 201639,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4271476032273374}),
#  ((u'_7jMembers_@download.gardeningenthusiast.com', u'7.38.9.7669'),
#   {'avgBlockingTime': 3816,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.42383898043178597}),
#  ((u'{F53C93F1-07D5-430c-86D4-C9531B27DFAF}', u'1.0.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 13927,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4227053140096619}),
#  ((u'{be006144-3bab-4e60-add9-050f9911e12f}', u'2.0.5942.34839'),
#   {'avgBlockingTime': 119282,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.42221566161275054}),
#  ((u'{e415cc51-3140-44b2-93a8-79cfb83c1f31}', u'1.0.0'),
#   {'avgBlockingTime': 82202,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.42189148013594285}),
#  ((u'sdtools@sharedir.com', u'1.6.0'),
#   {'avgBlockingTime': 2323970,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4204420480977917}),
#  ((u'ffext_basicchromeext@startpage24', u'1.97.38.1-signed.1-signed'),
#   {'avgBlockingTime': 21391,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4197761194029851}),
#  ((u'{9D7B21FA-0991-472C-8F8E-2CD6CC1CB7BC}', u'2.01.1-signed.1-signed'),
#   {'avgBlockingTime': 197327,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4180759795026638}),
#  ((u'jid1-4P0kohSJxU1qGg@jetpack', u'1.16.103'),
#   {'avgBlockingTime': 22573,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4173277004065767}),
#  ((u'{b9db16a4-6edc-47ec-a1f4-b86292ed211d}', u'5.4.1'),
#   {'avgBlockingTime': 491481,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.41649406048120735}),
#  ((u'{c07d1a49-9894-49ff-a594-38960ede8fb9}', u'3.3.1'),
#   {'avgBlockingTime': 952,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.415257196899209}),
#  ((u'tablang@mozdev.org', u'0.4.1.1-signed.1-signed'),
#   {'avgBlockingTime': 108616,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4110049809011699}),
#  ((u'@A3592ADB-854A-443A-854E-EB92130D470D', u'1.08.8.88'),
#   {'avgBlockingTime': 217389,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4082074979466192}),
#  ((u'speeddns@gmail.com', u'0.2.1-signed.1-signed'),
#   {'avgBlockingTime': 62247,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40765683656552704}),
#  ((u'{1BFCBDFC-41DB-11E1-9FC4-D3C94824019B}', u'3.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 7405952,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40710059171597635}),
#  ((u'avg@wtu3', u'3.5.0.0'),
#   {'avgBlockingTime': 51358,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4064811155648394}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.17.2016090400a172908'),
#   {'avgBlockingTime': 3405,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40572915324969727}),
#  ((u'HAX-BAR@TEAM-H.A.X', u'v1.1'),
#   {'avgBlockingTime': 217915,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40472175379426645}),
#  ((u'tabutilsfixed@addon.cn', u'1.5.2016.07.31'),
#   {'avgBlockingTime': 144156,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4026787220867828}),
#  ((u'{578e7caa-210f-4967-a0d3-88fe5b59a39f}', u'0.9.3.4'),
#   {'avgBlockingTime': 105512,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.40120416712957896}),
#  ((u'cpmanager@mozillaonline.com', u'2.48'),
#   {'avgBlockingTime': 155943,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.4000243842024321}),
#  ((u'{a182d6e5-aab8-0e32-ddd5-f043d20bd099}', u'1.1'),
#   {'avgBlockingTime': 84100,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3980044499108636}),
#  ((u'usablehomebutton@tanalin.com', u'1.4'),
#   {'avgBlockingTime': 133589,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.39712306402506287}),
#  ((u'_frMembers_@free.testforspeed.com', u'7.102.10.4993'),
#   {'avgBlockingTime': 76903,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3929761576271032}),
#  ((u'_g3Members_@free.easyphotoedit.com', u'7.38.9.11623'),
#   {'avgBlockingTime': 12966,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.39287040942888984}),
#  ((u'{804ddc07-30f8-4eae-9cb7-b49dec7aa67d}', u'2.0.5882.864'),
#   {'avgBlockingTime': 41409,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.389800227383466}),
#  ((u'urllister@binnyva.com', u'1.3.1-signed.1-signed'),
#   {'avgBlockingTime': 541717,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3891068107202529}),
#  ((u'chmfox@zhuoqiang.me', u'2.10.1-signed.1-signed'),
#   {'avgBlockingTime': 111564,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.38869884743500127}),
#  ((u'multipletab@piro.sakura.ne.jp', u'0.8.2016090401'),
#   {'avgBlockingTime': 6208,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.388598239793899}),
#  ((u'nextpage@yuanle.song', u'1.4.1'),
#   {'avgBlockingTime': 364870,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.38800591547539737}),
#  ((u'showmethepassword@alejandrobrizuela.com.ar', u'1.1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 74829,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3877654709887207}),
#  ((u'tabletools2@mingyi.org', u'1.17.1-signed.1-signed'),
#   {'avgBlockingTime': 1473784,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.37929225251630555}),
#  ((u'abs@avira.com', u'1.6.0'),
#   {'avgBlockingTime': 79653,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3745101892201172}),
#  ((u'firegestures@xuldev.org', u'1.8.7.1-signed'),
#   {'avgBlockingTime': 465,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.37449287423280975}),
#  ((u'jid0-tKjnEA5X3eBoP5HnqjBYQ4U3AcM@jetpack', u'0.9.17.1-signed.1-signed'),
#   {'avgBlockingTime': 14002,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.37112767638886884}),
#  ((u'vimperator@mozdev.org', u'3.14.0'),
#   {'avgBlockingTime': 166843,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3655338648584218}),
#  ((u'@focus-mode', u'0.0.2'),
#   {'avgBlockingTime': 6678,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3650695998431553}),
#  ((u'BestSearch@LukaszPolowczyk', u'2.0.1'),
#   {'avgBlockingTime': 5200,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3638936621853836}),
#  ((u'{c07d1a49-9894-49ff-a594-38960ede8fb9}', u'3.2.4'),
#   {'avgBlockingTime': 3205,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3621196494827708}),
#  ((u'_fvMembers_@free.directionsace.com', u'7.38.8.46177'),
#   {'avgBlockingTime': 283392,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3618971763514114}),
#  ((u'simplifyawesomebar@thelittlespark', u'0.4.8'),
#   {'avgBlockingTime': 148688,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3583457668783345}),
#  ((u'eagleget_ffext@eagleget.com', u'4.1.6'),
#   {'avgBlockingTime': 67396,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.35665508481172997}),
#  ((u'{d10d0bf8-f5b5-c8b4-a8b2-2b9879e08c5d}', u'2.7'),
#   {'avgBlockingTime': 3944,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3530170511761578}),
#  ((u'snaplinks@snaplinks.mozdev.org', u'2.4.3'),
#   {'avgBlockingTime': 311306,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3521356374307141}),
#  ((u'_eeMembers_@download.freeradiocast.com', u'7.38.8.46366'),
#   {'avgBlockingTime': 22880,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.35194056114967254}),
#  ((u'alx-ffdeveloper@amazon.com', u'3.0.1'),
#   {'avgBlockingTime': 448,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.34897698044436404}),
#  ((u'_e2Members_@free.coolpopulargames.com', u'7.38.8.45873'),
#   {'avgBlockingTime': 6414,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3468408578530551}),
#  ((u'_eeMembers_@download.freeradiocast.com', u'7.102.10.4225'),
#   {'avgBlockingTime': 88346,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.34381131259854}),
#  ((u'passwordconfidential@smartpc', u'1.1.10'),
#   {'avgBlockingTime': 9403,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.342681238686195}),
#  ((u'{8b86149f-01fb-4842-9dd8-4d7eb02fd055}', u'0.26.1-signed.1-signed'),
#   {'avgBlockingTime': 52824,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3412665449819418}),
#  ((u'mp4downloader@jeff.net', u'1.3.3.1-signed'),
#   {'avgBlockingTime': 45906,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3388189738625363}),
#  ((u'avg@toolbar', u'4.3.2.18'),
#   {'avgBlockingTime': 89527,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.33765088774045904}),
#  ((u'@new-xkit', u'7.7.3-amo-unlisted'),
#   {'avgBlockingTime': 12501,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.33593244676560435}),
#  ((u'{e1aaa9f8-4500-47f1-9a0a-b02bd60e4076}', u'48.0'),
#   {'avgBlockingTime': 477641,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3346384414816062}),
#  ((u'_brMembers_@free.yourtemplatefinder.com', u'7.38.8.45986'),
#   {'avgBlockingTime': 74517,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3308046516851638}),
#  ((u'e67f8350-7edf-11e3-baa7-0800200c9a66@fri-gate.org', u'2.2.1.1-signed'),
#   {'avgBlockingTime': 8695,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3306951434675278}),
#  ((u'dta@downthemall.net', u'3.0.6.20160914.00h00m36s'),
#   {'avgBlockingTime': 286,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3278381165378795}),
#  ((u'dmpluginff@westbyte.com', u'1.4.12'),
#   {'avgBlockingTime': 3577,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.32703086396991043}),
#  ((u'simplemail@telega.phpnet.us', u'2.90'),
#   {'avgBlockingTime': 30339,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.32606923536764304}),
#  ((u'tileview@DW-dev', u'6.1'),
#   {'avgBlockingTime': 84118,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3254818798045973}),
#  ((u'jid1-jwVSihNsgAw5jA@jetpack', u'1.1.187'),
#   {'avgBlockingTime': 2503,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3229353071335581}),
#  ((u'_foMembers_@free.flightsearchapp.com', u'7.38.8.46367'),
#   {'avgBlockingTime': 82223,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3221392431964863}),
#  ((u'leethax@leethax.net', u'2016.07.14'),
#   {'avgBlockingTime': 45771,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.322011433032193}),
#  ((u'avg@toolbar', u'4.2.9.726'),
#   {'avgBlockingTime': 111216,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.32090118237883863}),
#  ((u'jid1-vRJA7N8VwBoiXw@jetpack', u'1.1.1.1-signed'),
#   {'avgBlockingTime': 1678,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3190815852783523}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.18.2016090700a182622'),
#   {'avgBlockingTime': 3293,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3163378454714731}),
#  ((u'Clipper@OneNote.com', u'2.0.5'),
#   {'avgBlockingTime': 1919,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.315512708150745}),
#  ((u'searchyoutube@searchyoutube.fr', u'1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 613700,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.31475082226570633}),
#  ((u'wrc@avast.com', u'10.3.3.48'),
#   {'avgBlockingTime': 47729,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3141329008017575}),
#  ((u'{da8bd68d-8e90-41cd-8345-a71b294e72e6}', u'2.0.17.1'),
#   {'avgBlockingTime': 160260,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3140792043326824}),
#  ((u'tabnotifier@unusoft.it', u'2.2.1-signed.1-signed'),
#   {'avgBlockingTime': 487998,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.31116904481419777}),
#  ((u'fdm_ffext@freedownloadmanager.org', u'2.1.8'),
#   {'avgBlockingTime': 153589,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3108741175708642}),
#  ((u'@greatdealzu', u'0.0.3'),
#   {'avgBlockingTime': 477,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3104100234218472}),
#  ((u'jid1-VvY9NBlA26BanA@jetpack', u'1.2.9'),
#   {'avgBlockingTime': 14199,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3103983445421625}),
#  ((u'{8AA36F4F-6DC7-4c06-77AF-5035170634FE}', u'2016.8.4'),
#   {'avgBlockingTime': 107147,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3078611489207044}),
#  ((u'feedbar@efinke.com', u'8.0.4.1-signed.1-signed'),
#   {'avgBlockingTime': 1579,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3067615355119083}),
#  ((u'gpfs-firefox@ingtotaro.it', u'2016.5.31'),
#   {'avgBlockingTime': 575,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.30157984474222804}),
#  ((u'{a38384b3-2d1d-4f36-bc22-0f7ae402bcd7}', u'1.0.0.49'),
#   {'avgBlockingTime': 1867,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.3006430420621886}),
#  ((u'imgflashblocker@shimon.chohen', u'0.7.1-signed.1-signed'),
#   {'avgBlockingTime': 3529,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2997077673383611}),
#  ((u'_dzMembers_@www.pconverter.com', u'7.102.10.4851'),
#   {'avgBlockingTime': 49843,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.29962315914397786}),
#  ((u'mozilla_cc2@internetdownloadmanager.com', u'6.23.14'),
#   {'avgBlockingTime': 101015,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.29953821192328495}),
#  ((u'@statuser', u'0.1.4'),
#   {'avgBlockingTime': 2418,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.29852315724583806}),
#  ((u'{99392FC6-2524-D2F9-19D8-D4C27B7518F6}', u'3.0.3'),
#   {'avgBlockingTime': 1287018,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2932355105876056}),
#  ((u'treestyletab@piro.sakura.ne.jp', u'0.151.2015110200a161605'),
#   {'avgBlockingTime': 63985,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2898580332555612}),
#  ((u'guide-cfr-1@shield.mozilla.org', u'0.1.5'),
#   {'avgBlockingTime': 6033,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2897673045891322}),
#  ((u'magit@magit.com', u'1.1'),
#   {'avgBlockingTime': 20826,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2892294178454551}),
#  ((u'dcct@mingyi.org', u'0.27.1-signed.1-signed'),
#   {'avgBlockingTime': 5606,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2890096068934143}),
#  ((u'{0a3e0351-5d76-4318-ab65-29bfb7d6183c}', u'2.0.5826.21095'),
#   {'avgBlockingTime': 159677,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.28849485352522325}),
#  ((u'{f858758c-7649-4236-b05a-fce4d9cd89d2}', u'7.1.2.1'),
#   {'avgBlockingTime': 1526,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.28708897099869746}),
#  ((u'{41ca0b9f-fccf-4Ea1-b7c9-e379c1498afc}', u'0.6.3.1-signed.1-signed'),
#   {'avgBlockingTime': 79381,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2869543383909035}),
#  ((u'{1ced4832-f06e-413f-aa14-9eb63ad40ace}', u'1.1.1-signed.1-signed'),
#   {'avgBlockingTime': 277626,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2868607243149264}),
#  ((u'sessionhistorytree@daniel.dawson', u'1.0.1.1-signed.1-signed'),
#   {'avgBlockingTime': 126921,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2856880088856107}),
#  ((u'addon@ytdownloader.info', u'1.0.3'),
#   {'avgBlockingTime': 41635,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2853730101865839}),
#  ((u'furiganainserter@zorkzero.net', u'13'),
#   {'avgBlockingTime': 1796634,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.28306765498407743}),
#  ((u'ahrefs@AhrefsPteLtd', u'0.2.23'),
#   {'avgBlockingTime': 221783,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2807966304404347}),
#  ((u'jetpack-extension@dashlane.com', u'4.2.3'),
#   {'avgBlockingTime': 55535,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.28072874929726865}),
#  ((u'rpcontinued@requestpolicy.org', u'0.5.30'),
#   {'avgBlockingTime': 152956,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.27931536700044113}),
#  ((u'_beMembers_@free.dailylocalguide.com', u'7.38.9.7920'),
#   {'avgBlockingTime': 12673,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2741097425991074}),
#  ((u'{19F6FEE2-01F5-44F2-8618-1AE34A8111EF}', u'3.0'),
#   {'avgBlockingTime': 176303,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2736450768071977}),
#  ((u'{e30e9060-21d5-11e3-8224-0800200c9a66}', u'1.2.12'),
#   {'avgBlockingTime': 91540,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2720657794595671}),
#  ((u'abb@amazon.com', u'10.1607.15.512'),
#   {'avgBlockingTime': 23837,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.27068106178198365}),
#  ((u'firefox@schnaeppchenfuchs.com', u'1.0.1-signed.1-signed'),
#   {'avgBlockingTime': 103249,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.26912366606238436}),
#  ((u'idaremote@westbyte.com', u'1.6.3'),
#   {'avgBlockingTime': 86160,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2677243430837878}),
#  ((u'bestshopping@it.bestshopping.com', u'1.2.1.10'),
#   {'avgBlockingTime': 127895,
#    'hadCPOWBlocking': True,
#    'occurrenceFreq': 0.2666232169572366}),
#  ...]
